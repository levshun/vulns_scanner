# %%
from transformers import (AutoTokenizer, AutoModelForTokenClassification,
                         pipeline)
import pandas as pd
import re
from itertools import product
from pprint import pprint
import numpy as np
import pylcs
import psycopg2 as p2
from psycopg2 import sql
from collections import Counter
from tqdm import tqdm
from rapidfuzz import fuzz
from Levenshtein import ratio

pd.set_option('display.width', 20000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 200)

# %%
dbname = "vulns_scanner"
user = 'postgres'
password = 'postgres'
host = 'localhost'
port = '5432'

# %%
def get_df_from_bd(q):
    conn = p2.connect(dbname=dbname, user=user, password=password, host=host, port=port)
    cur = conn.cursor()
    cur.execute(q)
    colnames = [desc[0] for desc in cur.description]
    tuples = cur.fetchall()
    cur.close()
    df = pd.DataFrame(tuples, columns=colnames)
    return df

# %%
path_to_model = "/home/mikhail/Documents/pandan_study/vkr/vulns_scanner/mikhail_code/models/nuner_180525_full_dataset"
final_tokenizer = AutoTokenizer.from_pretrained(path_to_model, use_fast=True, add_prefix_space=True, local_files_only=True)
final_model = AutoModelForTokenClassification.from_pretrained(path_to_model, local_files_only=True)

# %%
df_test = pd.read_csv('df_200_not_in_stucco_v3_180525.csv')

# %%
def extract_ners(cve, tokenizer=final_tokenizer, model=final_model):
    token_classifier = pipeline(
        "token-classification", model=final_model, aggregation_strategy="first", tokenizer=final_tokenizer
    )
    result = token_classifier(cve)
    vendor = []
    product = []
    version = []
    vendor_probs = []
    product_probs = []
    version_probs = []

    for ner_item in result:
        if ner_item['entity_group'] == 'vendor':
            vendor.append(str.lower(ner_item['word'].strip()))
            vendor_probs.append(str.lower(str(ner_item['score'])))
        elif ner_item['entity_group'] == 'product':
            product.append(str.lower(str(ner_item['word'].strip())))
            product_probs.append(str.lower(str(ner_item['score'])))
        elif ner_item['entity_group'] == 'version':
            version.append(str.lower(str(ner_item['word'].strip())))
            version_probs.append(str.lower(str(ner_item['score'])))
    return {'ners': [vendor, product, version], 'scores': [vendor_probs, product_probs, version_probs]}

# %%
s = 'OX App Suite through 7.10.3 allows Information Exposure because a user can obtain the IP address and User-Agent string of a different user (via the session API during shared Drive access).'
extract_ners(s)
# Out:
# Device set to use cpu
# /home/mikhail/.local/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:398: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(
# {'ners': [[], ['ox app suite'], ['through 7.10.3']],
#  'scores': [[], ['0.9998378'], ['0.9999568']]}

# %%
df_test[['ners_list', 'scores_list']] = df_test['descr'].apply(lambda x: extract_ners(x)).apply(pd.Series)
df_test['vendor_ner'], df_test['product_ner'], df_test['version_ner'] = zip(*df_test['ners_list'])
df_test['vendor_score_ner'], df_test['product_score_ner'], df_test['version_score_ner'] = zip(*df_test['scores_list'])
# Out:
# Device set to use cpu
# /home/mikhail/.local/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:398: UserWarning: Tokenizer does not support real words, using fallback heuristic
#   warnings.warn(
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu

# %%
def deduplicate_using_probs(row, ner_type):
    if ner_type == 'product':
        product_ner = row['product_ner']
        product_score_ner = row['product_score_ner']
        if not product_ner or len(product_ner) == 1:
            return product_ner, product_score_ner
        else:
            max_idx = product_score_ner.index(max(product_score_ner))
            return [[product_ner[max_idx]], [product_score_ner[max_idx]]]
    elif ner_type == 'vendor':
        vendor_ner = row['vendor_ner']
        vendor_score_ner = row['vendor_score_ner']
        if not vendor_ner or len(vendor_ner) == 1:
            return vendor_ner, vendor_score_ner
        else:
            max_idx = vendor_score_ner.index(max(vendor_score_ner))
            return [[vendor_ner[max_idx]], [vendor_score_ner[max_idx]]]

# %%
df_test[['dedup_vendor', 'dedup_vendor_score']] = df_test.apply(lambda x: deduplicate_using_probs(x, 'vendor'), axis=1).apply(pd.Series)
df_test[['dedup_product', 'dedup_product_score']] = df_test.apply(lambda x: deduplicate_using_probs(x, 'product'), axis=1).apply(pd.Series)

# %%
df_test
# Out:
#              cve_id  cpe_id_pk      vendor                                      product  version                                                                                                                                                                                                    descr                                                                         initial_cpe  vendor_in_text  product_in_text                                                                                                                                                                                                ners_list                                                                                                                                        scores_list      vendor_ner                                                                                                                                                                                              product_ner                      version_ner vendor_score_ner                                                                                                              product_score_ner version_score_ner    dedup_vendor dedup_vendor_score           dedup_product dedup_product_score  true_version_in_predicted                                    matched_db_product matched_db_vendor
# 0    CVE-2021-34085     628902  glensawyer                                      mp3gain    1.3.4  Read access violation in the III_dequantize_sample function in mpglibDBL/layer3.c in mp3gain through 1.5.2-r2 allows remote attackers to cause a denial of service (application crash) or possibly h...                                 cpe:2.3:a:glensawyer:mp3gain:1.3.4:beta:*:*:*:*:*:*               0                1                                                                                                                                                                      [[], [mp3gain], [through 1.5.2-r2]]                                                                                                                   [[], [0.99991965], [0.99996096]]              []                                                                                                                                                                                                [mp3gain]               [through 1.5.2-r2]               []                                                                                                                   [0.99991965]      [0.99996096]              []                 []               [mp3gain]        [0.99991965]                          1                                               mp3gain        glensawyer
# 1     CVE-2014-7221     722762   teamspeak                                   teamspeak3  3.0.7.1  TeamSpeak Client 3.0.14 and earlier allows remote authenticated users to cause a denial of service (buffer overflow and application crash) by connecting to a channel with a different client instan...                           cpe:2.3:a:teamspeak:teamspeak3:3.0.7.1:*:*:*:client:*:*:*               1                0                                                                                                                                                                  [[], [teamspeak], [3.0.14 and earlier]]                                                                                                                     [[], [0.9999192], [0.9999383]]              []                                                                                                                                                                                              [teamspeak]             [3.0.14 and earlier]               []                                                                                                                    [0.9999192]       [0.9999383]              []                 []             [teamspeak]         [0.9999192]                          0                                             teamspeak         teamspeak
# 2     CVE-2018-7279     541558  alienvault  open_source_security_information_management      5.3                                                                                                                   A remote code execution issue was discovered in AlienVault USM and OSSIM before 5.5.1.  cpe:2.3:a:alienvault:open_source_security_information_management:5.3:*:*:*:*:*:*:*               1                0                                                                                                                                                                   [[alienvault], [usm], [before 5.5.1.]]                                                                                                           [[0.9999037], [0.9814162], [0.99995714]]    [alienvault]                                                                                                                                                                                                    [usm]                  [before 5.5.1.]      [0.9999037]                                                                                                                    [0.9814162]      [0.99995714]    [alienvault]        [0.9999037]                   [usm]         [0.9814162]                          0                                               usermin           usermin
# 3    CVE-2020-24743     472694    zohocorp            manageengine_applications_manager     14.5                                    An issue was found in /showReports.do Zoho ManageEngine Applications Manager up to 14550, allows attackers to gain escalated privileges via the resourceid parameter.    cpe:2.3:a:zohocorp:manageengine_applications_manager:14.5:build14540:*:*:*:*:*:*               0                0                                                                                                                                                 [[manageengine], [applications manager], [up to 14550,]]                                                                                                            [[0.95109195], [0.888083], [0.9999476]]  [manageengine]                                                                                                                                                                                   [applications manager]                   [up to 14550,]     [0.95109195]                                                                                                                     [0.888083]       [0.9999476]  [manageengine]       [0.95109195]  [applications manager]          [0.888083]                          0                                  applications_manager      manageengine
# 4    CVE-2020-24786     472744    zohocorp               manageengine_o365_manager_plus      4.3  An issue was discovered in Zoho ManageEngine Exchange Reporter Plus before build number 5510, AD360 before build number 4228, ADSelfService Plus before build number 5817, DataSecurity Plus before ...              cpe:2.3:a:zohocorp:manageengine_o365_manager_plus:4.3:4304:*:*:*:*:*:*               0                0  [[zoho], [manageengine exchange reporter plus, adselfservice plus, datasecurity plus, recovermanager plus, eventlog analyzer, adaudit plus, o365 manager plus, cloud security plus, admanager plus, ...  [[0.98405576], [0.9567048, 0.88903725, 0.9884461, 0.9938674, 0.98616344, 0.9817395, 0.962745, 0.9839506, 0.94795024, 0.59385043, 0.99802125], []]          [zoho]  [manageengine exchange reporter plus, adselfservice plus, datasecurity plus, recovermanager plus, eventlog analyzer, adaudit plus, o365 manager plus, cloud security plus, admanager plus, log360, j...                               []     [0.98405576]  [0.9567048, 0.88903725, 0.9884461, 0.9938674, 0.98616344, 0.9817395, 0.962745, 0.9839506, 0.94795024, 0.59385043, 0.99802125]                []          [zoho]       [0.98405576]          [java servlet]        [0.99802125]                          0  java_communications_services_delegated_administrator               sun
# ..              ...        ...         ...                                          ...      ...                                                                                                                                                                                                      ...                                                                                 ...             ...              ...                                                                                                                                                                                                      ...                                                                                                                                                ...             ...                                                                                                                                                                                                      ...                              ...              ...                                                                                                                            ...               ...             ...                ...                     ...                 ...                        ...                                                   ...               ...
# 195   CVE-2022-3550     169910       x.org                                     x_server   1.13.1  A vulnerability classified as critical was found in X.org Server. Affected by this vulnerability is the function _GetCountedString of the file xkb/xkb.c. The manipulation leads to buffer overflow....                                       cpe:2.3:a:x.org:x_server:1.13.1:*:*:*:*:*:*:*               1                0                                                                                                                                                                                [[], [x.org server.], []]                                                                                                                              [[], [0.9496948], []]              []                                                                                                                                                                                          [x.org server.]                               []               []                                                                                                                    [0.9496948]                []              []                 []         [x.org server.]         [0.9496948]                          0                                         x.org-xserver                 x
# 196  CVE-2020-11673     451620  total-soft                              responsive_poll    1.2.2  An issue was discovered in the Responsive Poll through 1.3.4 for Wordpress. It allows an unauthenticated user to manipulate polls, e.g., delete, clone, or view a hidden poll. This is due to the us...                    cpe:2.3:a:total-soft:responsive_poll:1.2.2:*:*:*:*:wordpress:*:*               1                0                                                                                                                                                                 [[], [responsive poll], [through 1.3.4]]                                                                                                                     [[], [0.9997986], [0.9999593]]              []                                                                                                                                                                                        [responsive poll]                  [through 1.3.4]               []                                                                                                                    [0.9997986]       [0.9999593]              []                 []       [responsive poll]         [0.9997986]                          1                                       responsive_poll        total-soft
# 197   CVE-2022-1253      80875    struktur                                     libde265    1.0.3  Heap-based Buffer Overflow in GitHub repository strukturag/libde265 prior to and including 1.0.8. The fix is established in commit 8e89fe0e175d2870c39486fdd09250b230ec10b8 but does not yet belong ...                                     cpe:2.3:a:struktur:libde265:1.0.3:*:*:*:*:*:*:*               1                1                                                                                                                                                                [[], [], [prior to and including 1.0.8.]]                                                                                                                             [[], [], [0.99994123]]              []                                                                                                                                                                                                       []  [prior to and including 1.0.8.]               []                                                                                                                             []      [0.99994123]              []                 []                      []                  []                          1
# 198  CVE-2019-20903     705053   atlassian                                  editor-core   98.2.2  The hyperlinks functionality in atlaskit/editor-core in before version 113.1.5 allows remote attackers to inject arbitrary HTML or JavaScript via a Cross-Site Scripting (XSS) vulnerability in link...                          cpe:2.3:a:atlassian:editor-core:98.2.2:*:*:*:*:node.js:*:*               0                1                                                                                                                                                                       [[], [], [before version 113.1.5]]                                                                                                                             [[], [], [0.99994594]]              []                                                                                                                                                                                                       []         [before version 113.1.5]               []                                                                                                                             []      [0.99994594]              []                 []                      []                  []                          0
# 199  CVE-2021-21353     597916       pugjs                                          pug   0.15.4  Pug is an npm package which is a high-performance template engine. In pug before version 3.0.1, if a remote attacker was able to control the `pretty` option of the pug compiler, e.g. if you spread...                                      cpe:2.3:a:pugjs:pug:0.15.4:*:*:*:*:node.js:*:*               0                1                                                                                                                                            [[], [pug, pug, pug, pug, pug, pug], [before version 3.0.1,]]                                                           [[], [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881], [0.9999499]]              []                                                                                                                                                                           [pug, pug, pug, pug, pug, pug]          [before version 3.0.1,]               []                                                          [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881]       [0.9999499]              []                 []                   [pug]        [0.99846953]                          1                                                   pug             pugjs
#
# [200 rows x 24 columns]

# %%
df_test[df_test.version.str.len().isin([6,5])]
# Out:
#              cve_id  cpe_id_pk       vendor          product version                                                                                                                                                                                                    descr                                                       initial_cpe  vendor_in_text  product_in_text                                                      ners_list                                                                               scores_list vendor_ner                     product_ner                                 version_ner vendor_score_ner                                                      product_score_ner       version_score_ner dedup_vendor dedup_vendor_score      dedup_product dedup_product_score  true_version_in_predicted matched_db_product matched_db_vendor
# 0    CVE-2021-34085     628902   glensawyer          mp3gain   1.3.4  Read access violation in the III_dequantize_sample function in mpglibDBL/layer3.c in mp3gain through 1.5.2-r2 allows remote attackers to cause a denial of service (application crash) or possibly h...               cpe:2.3:a:glensawyer:mp3gain:1.3.4:beta:*:*:*:*:*:*               0                1                            [[], [mp3gain], [through 1.5.2-r2]]                                                          [[], [0.99991965], [0.99996096]]         []                       [mp3gain]                          [through 1.5.2-r2]               []                                                           [0.99991965]            [0.99996096]           []                 []          [mp3gain]        [0.99991965]                          1            mp3gain        glensawyer
# 6    CVE-2019-13183     689916       flarum           flarum   0.1.0                                                                                           Flarum before 0.1.0-beta.9 allows CSRF against all POST endpoints, as demonstrated by changing admin settings.                 cpe:2.3:a:flarum:flarum:0.1.0:beta8.1:*:*:*:*:*:*               1                1                          [[], [flarum], [before 0.1.0-beta.9]]                                                           [[], [0.9974808], [0.99994767]]         []                        [flarum]                       [before 0.1.0-beta.9]               []                                                            [0.9974808]            [0.99994767]           []                 []           [flarum]         [0.9974808]                          1             flarum            flarum
# 8     CVE-2013-2175     549900      haproxy          haproxy  1.4.17  HAProxy 1.4 before 1.4.24 and 1.5 before 1.5-dev19, when configured to use hdr_ip or other "hdr_*" functions with a negative occurrence count, allows remote attackers to cause a denial of service ...                    cpe:2.3:a:haproxy:haproxy:1.4.17:*:*:*:*:*:*:*               1                1    [[], [haproxy], [1.4 before 1.4.24, 1.5 before 1.5-dev19,]]                                                 [[], [0.9999064], [0.9999666, 0.9999676]]         []                       [haproxy]  [1.4 before 1.4.24, 1.5 before 1.5-dev19,]               []                                                            [0.9999064]  [0.9999666, 0.9999676]           []                 []          [haproxy]         [0.9999064]                          0            haproxy           netgate
# 9    CVE-2016-10714     422757          zsh              zsh   4.2.2                                                                                 In zsh before 5.3, an off-by-one error resulted in undersized buffers that were intended to support PATH_MAX characters.                             cpe:2.3:a:zsh:zsh:4.2.2:*:*:*:*:*:*:*               1                1                                     [[], [zsh], [before 5.3,]]                                                           [[], [0.9995414], [0.99995625]]         []                           [zsh]                               [before 5.3,]               []                                                            [0.9995414]            [0.99995625]           []                 []              [zsh]         [0.9995414]                          1                zsh               zsh
# 10    CVE-2023-4393     375964  liquidfiles      liquidfiles  1.6.23                         HTML and SMTP injections on the registration page of LiquidFiles versions 3.7.13 and below, allow an attacker to perform more advanced phishing attacks against an organization.            cpe:2.3:a:liquidfiles:liquidfiles:1.6.23:*:*:*:*:*:*:*               1                1                       [[], [liquidfiles], [3.7.13 and below,]]                                                             [[], [0.99991], [0.83767396]]         []                   [liquidfiles]                         [3.7.13 and below,]               []                                                              [0.99991]            [0.83767396]           []                 []      [liquidfiles]           [0.99991]                          0        liquidfiles       liquidfiles
# ..              ...        ...          ...              ...     ...                                                                                                                                                                                                      ...                                                               ...             ...              ...                                                            ...                                                                                       ...        ...                             ...                                         ...              ...                                                                    ...                     ...          ...                ...                ...                 ...                        ...                ...               ...
# 195   CVE-2022-3550     169910        x.org         x_server  1.13.1  A vulnerability classified as critical was found in X.org Server. Affected by this vulnerability is the function _GetCountedString of the file xkb/xkb.c. The manipulation leads to buffer overflow....                     cpe:2.3:a:x.org:x_server:1.13.1:*:*:*:*:*:*:*               1                0                                      [[], [x.org server.], []]                                                                     [[], [0.9496948], []]         []                 [x.org server.]                                          []               []                                                            [0.9496948]                      []           []                 []    [x.org server.]         [0.9496948]                          0      x.org-xserver                 x
# 196  CVE-2020-11673     451620   total-soft  responsive_poll   1.2.2  An issue was discovered in the Responsive Poll through 1.3.4 for Wordpress. It allows an unauthenticated user to manipulate polls, e.g., delete, clone, or view a hidden poll. This is due to the us...  cpe:2.3:a:total-soft:responsive_poll:1.2.2:*:*:*:*:wordpress:*:*               1                0                       [[], [responsive poll], [through 1.3.4]]                                                            [[], [0.9997986], [0.9999593]]         []               [responsive poll]                             [through 1.3.4]               []                                                            [0.9997986]             [0.9999593]           []                 []  [responsive poll]         [0.9997986]                          1    responsive_poll        total-soft
# 197   CVE-2022-1253      80875     struktur         libde265   1.0.3  Heap-based Buffer Overflow in GitHub repository strukturag/libde265 prior to and including 1.0.8. The fix is established in commit 8e89fe0e175d2870c39486fdd09250b230ec10b8 but does not yet belong ...                   cpe:2.3:a:struktur:libde265:1.0.3:*:*:*:*:*:*:*               1                1                      [[], [], [prior to and including 1.0.8.]]                                                                    [[], [], [0.99994123]]         []                              []             [prior to and including 1.0.8.]               []                                                                     []            [0.99994123]           []                 []                 []                  []                          1
# 198  CVE-2019-20903     705053    atlassian      editor-core  98.2.2  The hyperlinks functionality in atlaskit/editor-core in before version 113.1.5 allows remote attackers to inject arbitrary HTML or JavaScript via a Cross-Site Scripting (XSS) vulnerability in link...        cpe:2.3:a:atlassian:editor-core:98.2.2:*:*:*:*:node.js:*:*               0                1                             [[], [], [before version 113.1.5]]                                                                    [[], [], [0.99994594]]         []                              []                    [before version 113.1.5]               []                                                                     []            [0.99994594]           []                 []                 []                  []                          0
# 199  CVE-2021-21353     597916        pugjs              pug  0.15.4  Pug is an npm package which is a high-performance template engine. In pug before version 3.0.1, if a remote attacker was able to control the `pretty` option of the pug compiler, e.g. if you spread...                    cpe:2.3:a:pugjs:pug:0.15.4:*:*:*:*:node.js:*:*               0                1  [[], [pug, pug, pug, pug, pug, pug], [before version 3.0.1,]]  [[], [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881], [0.9999499]]         []  [pug, pug, pug, pug, pug, pug]                     [before version 3.0.1,]               []  [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881]             [0.9999499]           []                 []              [pug]        [0.99846953]                          1                pug             pugjs
#
# [128 rows x 24 columns]

# %%
print(df_test['vendor_in_text'].sum())
df_test[(df_test['vendor_ner'].astype(str) != '[]') & 
        (df_test['vendor_in_text'] == 1)]
# Out:
# 107
#                cve_id  cpe_id_pk       vendor                                                       product           version                                                                                                                                                                                                    descr                                                                                       initial_cpe  vendor_in_text  product_in_text                                                                                                                                                                                                ners_list                                                                                                                                                                                              scores_list                                                vendor_ner                                                                                                           product_ner                                                                                                                                         version_ner                                                                            vendor_score_ner                                                                             product_score_ner                                                                                    version_score_ner      dedup_vendor dedup_vendor_score                 dedup_product dedup_product_score  true_version_in_predicted                               matched_db_product                    matched_db_vendor
# 2       CVE-2018-7279     541558   alienvault                   open_source_security_information_management               5.3                                                                                                                   A remote code execution issue was discovered in AlienVault USM and OSSIM before 5.5.1.                cpe:2.3:a:alienvault:open_source_security_information_management:5.3:*:*:*:*:*:*:*               1                0                                                                                                                                                                   [[alienvault], [usm], [before 5.5.1.]]                                                                                                                                                                 [[0.9999037], [0.9814162], [0.99995714]]                                              [alienvault]                                                                                                                 [usm]                                                                                                                                     [before 5.5.1.]                                                                                 [0.9999037]                                                                                   [0.9814162]                                                                                         [0.99995714]      [alienvault]        [0.9999037]                         [usm]         [0.9814162]                          0                                          usermin                              usermin
# 5       CVE-2013-3607     553572   supermicro                                                      x9dax-if                 -  Multiple stack-based buffer overflows in the web interface in the Intelligent Platform Management Interface (IPMI) implementation on Supermicro H8DC*, H8DG*, H8SCM-F, H8SGL-F, H8SM*, X7SP*, X8DT*,...                                                     cpe:2.3:h:supermicro:x9dax-if:-:*:*:*:*:*:*:*               1                0                                                                                                                                                                                   [[supermicro], [], []]                                                                                                                                                                                    [[0.9989392], [], []]                                              [supermicro]                                                                                                                    []                                                                                                                                                  []                                                                                 [0.9989392]                                                                                            []                                                                                                   []      [supermicro]        [0.9989392]                            []                  []                          0
# 7      CVE-2018-15121     522169        auth0                                                        aspnet                 -  An issue was discovered in Auth0 auth0-aspnet and auth0-aspnet-owin. Affected packages do not use or validate the state parameter of the OAuth 2.0 and OpenID Connect protocols. This leaves applica...                                                            cpe:2.3:a:auth0:aspnet:-:*:*:*:*:*:*:*               1                1                                                                                                                                                  [[auth0], [auth0-aspnet, oauth, openid connect], [2.0]]                                                                                                                                         [[0.99983096], [0.92818856, 0.9774277, 0.88269305], [0.9996136]]                                                   [auth0]                                                                                 [auth0-aspnet, oauth, openid connect]                                                                                                                                               [2.0]                                                                                [0.99983096]                                                           [0.92818856, 0.9774277, 0.88269305]                                                                                          [0.9996136]           [auth0]       [0.99983096]                       [oauth]         [0.9774277]                          0                                            oauth                            atlassian
# 13      CVE-2014-4700     719860       citrix                                                    xendesktop               4.0  Citrix XenDesktop 7.x, 5.x, and 4.x, when pooled random desktop groups is enabled and ShutdownDesktopsAfterUse is disabled, allows local guest users to gain access to another user's desktop via un...                                                     cpe:2.3:a:citrix:xendesktop:4.0:*:*:*:*:*:*:*               1                1                                                                                                                                                             [[citrix], [xendesktop], [7.x,, 5.x,, 4.x,]]                                                                                                                                             [[0.999882], [0.9998907], [0.9999678, 0.9999691, 0.9999697]]                                                  [citrix]                                                                                                          [xendesktop]                                                                                                                                  [7.x,, 5.x,, 4.x,]                                                                                  [0.999882]                                                                                   [0.9998907]                                                                    [0.9999678, 0.9999691, 0.9999697]          [citrix]         [0.999882]                  [xendesktop]         [0.9998907]                          0                                       xendesktop                               citrix
# 23      CVE-2023-6998     414164      coolkit                                                       ewelink            4.13.1                           Improper privilege management vulnerability in CoolKit Technology eWeLink on Android and iOS allows application lockscreen bypass.This issue affects eWeLink before 5.2.0.\n\n                                              cpe:2.3:a:coolkit:ewelink:4.13.1:*:*:*:*:android:*:*               1                1                                                                                                                                                         [[coolkit], [ewelink, ewelink], [before 5.2.0.]]                                                                                                                                                       [[0.9544912], [0.9998672, 0.9998958], [0.9999499]]                                                 [coolkit]                                                                                                    [ewelink, ewelink]                                                                                                                                     [before 5.2.0.]                                                                                 [0.9544912]                                                                        [0.9998672, 0.9998958]                                                                                          [0.9999499]         [coolkit]        [0.9544912]                     [ewelink]         [0.9998958]                          1                                          ewelink                              coolkit
# 33      CVE-2016-1409     426211        cisco                                                           ios      12.1\(1\)xd2  The Neighbor Discovery (ND) protocol implementation in the IPv6 stack in Cisco IOS XE 2.1 through 3.17S, IOS XR 2.0.0 through 5.3.2, and NX-OS allows remote attackers to cause a denial of service ...                                                    cpe:2.3:o:cisco:ios:12.1\(1\)xd2:*:*:*:*:*:*:*               1                1                                                                                                                                                [[cisco], [], [2.1 through 3.17s,, 2.0.0 through 5.3.2,]]                                                                                                                                                                [[0.9998908], [], [0.9999612, 0.9999633]]                                                   [cisco]                                                                                                                    []                                                                                                          [2.1 through 3.17s,, 2.0.0 through 5.3.2,]                                                                                 [0.9998908]                                                                                            []                                                                               [0.9999612, 0.9999633]           [cisco]        [0.9998908]                            []                  []                          0
# 40      CVE-2014-1740     715763       google                                                        chrome      34.0.1847.78  Multiple use-after-free vulnerabilities in net/websockets/websocket_job.cc in the WebSockets implementation in Google Chrome before 34.0.1847.137 allow remote attackers to cause a denial of servic...                                                cpe:2.3:a:google:chrome:34.0.1847.78:*:*:*:*:*:*:*               1                1                                                                                                                                                             [[google], [chrome], [before 34.0.1847.137]]                                                                                                                                                                 [[0.9998888], [0.9999132], [0.99996156]]                                                  [google]                                                                                                              [chrome]                                                                                                                              [before 34.0.1847.137]                                                                                 [0.9998888]                                                                                   [0.9999132]                                                                                         [0.99996156]          [google]        [0.9998888]                      [chrome]         [0.9999132]                          0                                           chrome                               google
# 53     CVE-2020-10591     448076      walmart                                                       concord            0.72.0  An issue was discovered in Walmart Labs Concord before 1.44.0. CORS Access-Control-Allow-Origin headers have a potentially unsafe dependency on Origin headers, and are not configurable. This allow...                                                    cpe:2.3:a:walmart:concord:0.72.0:*:*:*:*:*:*:*               1                1                                                                                                                                                                        [[walmart], [], [before 1.44.0.]]                                                                                                                                                                           [[0.8405717], [], [0.9999189]]                                                 [walmart]                                                                                                                    []                                                                                                                                    [before 1.44.0.]                                                                                 [0.8405717]                                                                                            []                                                                                          [0.9999189]         [walmart]        [0.8405717]                            []                  []                          1
# 58      CVE-2022-4876     219422      kaltura                                                       mwembed              2.41  A vulnerability was found in Kaltura mwEmbed up to 2.96.rc1 and classified as problematic. This issue affects some unknown processing of the file includes/DefaultSettings.php. The manipulation of ...                                                    cpe:2.3:a:kaltura:mwembed:2.41:rc2:*:*:*:*:*:*               1                1                                                                                                                          [[kaltura], [mwembed], [up to 2.96.rc1, to, upgrading to version 2.96.rc2, to]]                                                                                                                                [[0.97595686], [0.9998877], [0.9999277, 0.5686604, 0.9999056, 0.6301625]]                                                 [kaltura]                                                                                                             [mwembed]                                                                                             [up to 2.96.rc1, to, upgrading to version 2.96.rc2, to]                                                                                [0.97595686]                                                                                   [0.9998877]                                                         [0.9999277, 0.5686604, 0.9999056, 0.6301625]         [kaltura]       [0.97595686]                     [mwembed]         [0.9998877]                          1                                          mwembed                              kaltura
# 65     CVE-2023-49183     393386  nextscripts                                   social_networks_auto_poster            4.3.14  Improper Neutralization of Input During Web Page Generation ('Cross-site Scripting') vulnerability in NextScripts NextScripts: Social Networks Auto-Poster allows Reflected XSS.This issue affects N...                    cpe:2.3:a:nextscripts:social_networks_auto_poster:4.3.14:*:*:*:*:wordpress:*:*               1                0                                                                                                                                                      [[nextscripts, nextscripts:], [], [through 4.4.2.]]                                                                                                                                                                [[0.9993755, 0.7670635], [], [0.9999251]]                               [nextscripts, nextscripts:]                                                                                                                    []                                                                                                                                    [through 4.4.2.]                                                                      [0.9993755, 0.7670635]                                                                                            []                                                                                          [0.9999251]     [nextscripts]        [0.9993755]                            []                  []                          1
# 66      CVE-2018-0463     507001        cisco                                 network_services_orchestrator             1.2.0  A vulnerability in the Cisco Network Plug and Play server component of Cisco Network Services Orchestrator (NSO) could allow an unauthenticated, remote attacker to gain unauthorized access to conf...                                 cpe:2.3:a:cisco:network_services_orchestrator:1.2.0:*:*:*:*:*:*:*               1                0                                                                                                                                                                   [[cisco, cisco, cisco, cisco], [], []]                                                                                                                                                   [[0.9999018, 0.9999032, 0.999894, 0.99984694], [], []]                              [cisco, cisco, cisco, cisco]                                                                                                                    []                                                                                                                                                  []                                                [0.9999018, 0.9999032, 0.999894, 0.99984694]                                                                                            []                                                                                                   []           [cisco]        [0.9999032]                            []                  []                          0
# 69     CVE-2023-26262     322153     sitecore                                           experience_platform               9.0  An issue was discovered in Sitecore XP/XM 10.3. As an authenticated Sitecore user, a unrestricted language file upload vulnerability exists the can lead to direct code execution on the content man...                                          cpe:2.3:a:sitecore:experience_platform:9.0:-:*:*:*:*:*:*               1                0                                                                                                                                                                      [[sitecore, sitecore], [], [10.3.]]                                                                                                                                                                [[0.9997327, 0.9991725], [], [0.9999467]]                                      [sitecore, sitecore]                                                                                                                    []                                                                                                                                             [10.3.]                                                                      [0.9997327, 0.9991725]                                                                                            []                                                                                          [0.9999467]        [sitecore]        [0.9997327]                            []                  []                          0
# 70     CVE-2019-25056     705828      bromite                                                       bromite      73.0.3683.79  In Bromite through 78.0.3904.130, there are adblock rules in the release APK; therefore, probing which resources are blocked and which aren't can identify the application version and defeat the Us...                                              cpe:2.3:a:bromite:bromite:73.0.3683.79:*:*:*:*:*:*:*               1                1                                                                                                                                                                [[bromite], [], [through 78.0.3904.130,]]                                                                                                                                                                          [[0.9018276], [], [0.99994177]]                                                 [bromite]                                                                                                                    []                                                                                                                            [through 78.0.3904.130,]                                                                                 [0.9018276]                                                                                            []                                                                                         [0.99994177]         [bromite]        [0.9018276]                            []                  []                          0
# 71      CVE-2009-1729     227413          sun                            java_system_communications_express               6.3  Multiple cross-site scripting (XSS) vulnerabilities in Sun Java System Communications Express 6 2005Q4 (aka 6.2) and 6.3 allow remote attackers to inject arbitrary web script or HTML via (1) the a...                            cpe:2.3:a:sun:java_system_communications_express:6.3:*:sparc:*:*:*:*:*               1                0                                                                                                                          [[sun], [java system communications, personal address book], [express, 6, 6.3]]                                                                                                                              [[0.9999095], [0.86648446, 0.9986627], [0.99540627, 0.9971763, 0.99995315]]                                                     [sun]                                                                   [java system communications, personal address book]                                                                                                                                   [express, 6, 6.3]                                                                                 [0.9999095]                                                                       [0.86648446, 0.9986627]                                                                  [0.99540627, 0.9971763, 0.99995315]             [sun]        [0.9999095]       [personal address book]         [0.9986627]                          1           professional_home_page_tools_guestbook         professional_home_page_tools
# 75      CVE-2022-0864      76989  updraftplus                                                   updraftplus            1.9.64  The UpdraftPlus WordPress Backup Plugin WordPress plugin before 1.22.9 does not sanitise and escape the updraft_interval parameter before outputting it back in an admin page, leading to a Reflecte...                                    cpe:2.3:a:updraftplus:updraftplus:1.9.64:*:*:*:*:wordpress:*:*               1                1                                                                                                                                          [[updraftplus], [wordpress backup, wordpress], [before 1.22.9]]                                                                                                                                                    [[0.9832593], [0.93556273, 0.70108855], [0.99995124]]                                             [updraftplus]                                                                                         [wordpress backup, wordpress]                                                                                                                                     [before 1.22.9]                                                                                 [0.9832593]                                                                      [0.93556273, 0.70108855]                                                                                         [0.99995124]     [updraftplus]        [0.9832593]            [wordpress backup]        [0.93556273]                          1                      wordpress_backup_to_dropbox  wordpress_backup_to_dropbox_project
# 76     CVE-2024-24396     270222   stimulsoft                                                  dashboard.js          2022.4.3    Cross Site Scripting vulnerability in Stimulsoft GmbH Stimulsoft Dashboard.JS before v.2024.1.2 allows a remote attacker to execute arbitrary code via a crafted payload to the search bar component.                                    cpe:2.3:a:stimulsoft:dashboard.js:2022.4.3:*:*:*:*:node.js:*:*               1                1                                                                                                                                                        [[stimulsoft], [stimulsoft], [before v.2024.1.2]]                                                                                                                                                                [[0.9993554], [0.51689875], [0.99902797]]                                              [stimulsoft]                                                                                                          [stimulsoft]                                                                                                                                 [before v.2024.1.2]                                                                                 [0.9993554]                                                                                  [0.51689875]                                                                                         [0.99902797]      [stimulsoft]        [0.9993554]                  [stimulsoft]        [0.51689875]                          0  ons_15216_optical_add_drop_multiplexer_software                                cisco
# 78      CVE-2017-5670     673127     riverbed                                                          rios             9.2.0  Riverbed RiOS through 9.6.0 deletes the secure vault with the rm program (not shred or srm), which makes it easier for physically proximate attackers to obtain sensitive information by reading raw...                                                       cpe:2.3:o:riverbed:rios:9.2.0:*:*:*:*:*:*:*               1                1                                                                                                                                                                    [[riverbed], [rios], [through 9.6.0]]                                                                                                                                                                 [[0.9977552], [0.59904087], [0.9999435]]                                                [riverbed]                                                                                                                [rios]                                                                                                                                     [through 9.6.0]                                                                                 [0.9977552]                                                                                  [0.59904087]                                                                                          [0.9999435]        [riverbed]        [0.9977552]                        [rios]        [0.59904087]                          1                                             rios                             riverbed
# 82      CVE-2020-2090     467997      jenkins                                                    amazon_ec2               1.9  A cross-site request forgery vulnerability in Jenkins Amazon EC2 Plugin 1.47 and earlier allows attackers to connect to an attacker-specified URL within the AWS region using attacker-specified cre...                                              cpe:2.3:a:jenkins:amazon_ec2:1.9:*:*:*:*:jenkins:*:*               1                0                                                                                                                                                            [[jenkins amazon], [ec2], [1.47 and earlier]]                                                                                                                                                                [[0.45916593], [0.9699536], [0.99991107]]                                          [jenkins amazon]                                                                                                                 [ec2]                                                                                                                                  [1.47 and earlier]                                                                                [0.45916593]                                                                                   [0.9699536]                                                                                         [0.99991107]  [jenkins amazon]       [0.45916593]                         [ec2]         [0.9699536]                          1                                              ec2                              jenkins
# 86      CVE-2001-0990     728432       inter7                                                      vpopmail               4.8  Inter7 vpopmail 4.10.35 and earlier, when using the MySQL module, compiles authentication information in cleartext into the libvpopmail.a library, which allows local users to obtain the MySQL user...                                                       cpe:2.3:a:inter7:vpopmail:4.8:*:*:*:*:*:*:*               1                1                                                                                                                                                 [[inter7], [vpopmail, vpopmail], [4.10.35 and earlier,]]                                                                                                                                                     [[0.99530005], [0.9952283, 0.97308946], [0.9998743]]                                                  [inter7]                                                                                                  [vpopmail, vpopmail]                                                                                                                              [4.10.35 and earlier,]                                                                                [0.99530005]                                                                       [0.9952283, 0.97308946]                                                                                          [0.9998743]          [inter7]       [0.99530005]                    [vpopmail]         [0.9952283]                          0                                         vpopmail                               inter7
# 87      CVE-2016-6399     439689        cisco                      ace_application_control_engine_module_a4               1.0  Cisco ACE30 Application Control Engine Module through A5 3.3 and ACE 4700 Application Control Engine appliances through A5 3.3 allow remote attackers to cause a denial of service (device reload) v...                        cpe:2.3:a:cisco:ace_application_control_engine_module_a4:1.0:*:*:*:*:*:*:*               1                0                                                                                                                                                        [[cisco], [], [through a5, 3.3, through a5, 3.3]]                                                                                                                                      [[0.99990594], [], [0.99954045, 0.99986064, 0.99946094, 0.9999033]]                                                   [cisco]                                                                                                                    []                                                                                                                  [through a5, 3.3, through a5, 3.3]                                                                                [0.99990594]                                                                                            []                                                      [0.99954045, 0.99986064, 0.99946094, 0.9999033]           [cisco]       [0.99990594]                            []                  []                          0
# 89     CVE-2022-22984     103886         snyk                                                      snyk_cli             1.3.1  The package snyk before 1.1064.0; the package snyk-mvn-plugin before 2.31.3; the package snyk-gradle-plugin before 3.24.5; the package @snyk/snyk-cocoapods-plugin before 2.5.3; the package snyk-sb...                                                       cpe:2.3:a:snyk:snyk_cli:1.3.1:*:*:*:*:*:*:*               1                0  [[snyk, snyk], [snyk, snyk-mvn-plugin, snyk-gradle-plugin, snyk-sbt-plugin, snyk-python-plugin, snyk-docker-plugin, snyk, teamcity], [before 1.1064.0;, before 2.31.3;, before 3.24.5;, before 2.5.3...  [[0.9827137, 0.9985752], [0.9985032, 0.9998196, 0.99985504, 0.99981064, 0.99977845, 0.99979514, 0.9972339, 0.7386806], [0.9998791, 0.9997645, 0.9998817, 0.9998554, 0.9998132, 0.9993222, 0.9994785,...                                              [snyk, snyk]  [snyk, snyk-mvn-plugin, snyk-gradle-plugin, snyk-sbt-plugin, snyk-python-plugin, snyk-docker-plugin, snyk, teamcity]  [before 1.1064.0;, before 2.31.3;, before 3.24.5;, before 2.5.3;, before 2.16.2;, before 1.24.2;, before 5.6.5;, before 1.1.6, prior to that date]                                                                      [0.9827137, 0.9985752]  [0.9985032, 0.9998196, 0.99985504, 0.99981064, 0.99977845, 0.99979514, 0.9972339, 0.7386806]  [0.9998791, 0.9997645, 0.9998817, 0.9998554, 0.9998132, 0.9993222, 0.9994785, 0.9997512, 0.7709392]            [snyk]        [0.9985752]          [snyk-gradle-plugin]        [0.99985504]                          1                                  snyk_gradle_cli                                 snyk
# 93     CVE-2021-30476     622414    hashicorp                                            terraform_provider             1.3.1                                          HashiCorp Terraform’s Vault Provider (terraform-provider-vault) did not correctly configure GCE-type bound labels for Vault’s GCP auth method. Fixed in 2.19.1.                                    cpe:2.3:a:hashicorp:terraform_provider:1.3.1:*:*:*:*:vault:*:*               1                0                                                                                                                                                                  [[hashicorp], [terraform’s], [2.19.1.]]                                                                                                                                                               [[0.99987817], [0.50133723], [0.89815426]]                                               [hashicorp]                                                                                                         [terraform’s]                                                                                                                                           [2.19.1.]                                                                                [0.99987817]                                                                                  [0.50133723]                                                                                         [0.89815426]       [hashicorp]       [0.99987817]                 [terraform’s]        [0.50133723]                          0                 water_operations_for_waternamics                                  ibm
# 101    CVE-2023-26347     322374        adobe                                                    coldfusion              2023  Adobe ColdFusion versions 2023.5 (and earlier) and 2021.11 (and earlier) are affected by an Improper Access Control vulnerability that could result in a Security feature bypass. An unauthenticated...                                                     cpe:2.3:a:adobe:coldfusion:2023:-:*:*:*:*:*:*               1                1                                                                                                                                                               [[adobe], [coldfusion], [2023.5, 2021.11]]                                                                                                                                                        [[0.9999137], [0.999925], [0.99717975, 0.999686]]                                                   [adobe]                                                                                                          [coldfusion]                                                                                                                                   [2023.5, 2021.11]                                                                                 [0.9999137]                                                                                    [0.999925]                                                                               [0.99717975, 0.999686]           [adobe]        [0.9999137]                  [coldfusion]          [0.999925]                          0                                       coldfusion                                adobe
# 102     CVE-2013-1881     548297        gnome                                                       librsvg            2.18.2  GNOME libsvg before 2.39.0 allows remote attackers to read arbitrary files via an XML document containing an external entity declaration in conjunction with an entity reference, related to an XML ...                                                      cpe:2.3:a:gnome:librsvg:2.18.2:*:*:*:*:*:*:*               1                0                                                                                                                                                                     [[gnome], [libsvg], [before 2.39.0]]                                                                                                                                                                [[0.99991405], [0.9999193], [0.99995774]]                                                   [gnome]                                                                                                              [libsvg]                                                                                                                                     [before 2.39.0]                                                                                [0.99991405]                                                                                   [0.9999193]                                                                                         [0.99995774]           [gnome]       [0.99991405]                      [libsvg]         [0.9999193]                          1                                          librsvg                                gnome
# 106    CVE-2023-28617     330485          gnu                                                      org_mode             6.22a      org-babel-execute:latex in ob-latex.el in Org Mode through 9.6.1 for GNU Emacs allows attackers to execute arbitrary commands via a file name or directory name that contains shell metacharacters.                                                cpe:2.3:a:gnu:org_mode:6.22a:*:*:*:*:gnu_emacs:*:*               1                0                                                                                                                                                                     [[gnu], [org mode], [through 9.6.1]]                                                                                                                                                                 [[0.9831465], [0.8993225], [0.99994797]]                                                     [gnu]                                                                                                            [org mode]                                                                                                                                     [through 9.6.1]                                                                                 [0.9831465]                                                                                   [0.8993225]                                                                                         [0.99994797]             [gnu]        [0.9831465]                    [org mode]         [0.8993225]                          0                                         org_mode                                  gnu
# 107    CVE-2023-29439     335629   fooplugins                                                    foogallery            2.0.30                                                                                           Unauth. Reflected Cross-Site Scripting (XSS) vulnerability in FooPlugins FooGallery plugin <= 2.2.35 versions.                                      cpe:2.3:a:fooplugins:foogallery:2.0.30:*:*:*:*:wordpress:*:*               1                1                                                                                                                                                                [[fooplugins], [foogallery], [<= 2.2.35]]                                                                                                                                                                   [[0.999887], [0.9999163], [0.9999552]]                                              [fooplugins]                                                                                                          [foogallery]                                                                                                                                         [<= 2.2.35]                                                                                  [0.999887]                                                                                   [0.9999163]                                                                                          [0.9999552]      [fooplugins]         [0.999887]                  [foogallery]         [0.9999163]                          1                                       foogallery                           fooplugins
# 110     CVE-2021-3829     635684     openwhyd                                                      openwhyd            1.44.8                                                                                                                                              openwhyd is vulnerable to URL Redirection to Untrusted Site                                                  cpe:2.3:a:openwhyd:openwhyd:1.44.8:*:*:*:*:*:*:*               1                1                                                                                                                                                                                     [[openwhyd], [], []]                                                                                                                                                                                    [[0.5442839], [], []]                                                [openwhyd]                                                                                                                    []                                                                                                                                                  []                                                                                 [0.5442839]                                                                                            []                                                                                                   []        [openwhyd]        [0.5442839]                            []                  []                          0
# ...
# 170     CVE-2014-4301     719358       ajenti                                                        ajenti             1.2.6  Multiple cross-site scripting (XSS) vulnerabilities in the respond_error function in routing.py in Eugene Pankov Ajenti before 1.2.21.7 allow remote attackers to inject arbitrary web script or HTM...                                                       cpe:2.3:a:ajenti:ajenti:1.2.6:*:*:*:*:*:*:*               1                1                                                                                                                                                           [[eugene pankov], [ajenti], [before 1.2.21.7]]                                                                                                                                                                 [[0.7121296], [0.9990478], [0.99994016]]                                           [eugene pankov]                                                                                                              [ajenti]                                                                                                                                   [before 1.2.21.7]                                                                                 [0.7121296]                                                                                   [0.9990478]                                                                                         [0.99994016]   [eugene pankov]        [0.7121296]                      [ajenti]         [0.9990478]                          1                                           ajenti                               ajenti
# 172     CVE-2004-0095        541       mcafee                                          epolicy_orchestrator             3.6.0  McAfee ePolicy Orchestrator agent allows remote attackers to cause a denial of service (memory consumption and crash) and possibly execute arbitrary code via an HTTP POST request with an invalid C...                                         cpe:2.3:a:mcafee:epolicy_orchestrator:3.6.0:*:*:*:*:*:*:*               1                0                                                                                                                                                             [[mcafee], [epolicy orchestrator agent], []]                                                                                                                                                                          [[0.99988616], [0.9998781], []]                                                  [mcafee]                                                                                          [epolicy orchestrator agent]                                                                                                                                                  []                                                                                [0.99988616]                                                                                   [0.9998781]                                                                                                   []          [mcafee]       [0.99988616]  [epolicy orchestrator agent]         [0.9998781]                          0                       epolicy_orchestrator_agent                   network_associates
# 174     CVE-2020-7934     500873      liferay                                                liferay_portal             7.2.0  In LifeRay Portal CE 7.1.0 through 7.2.1 GA2, the First Name, Middle Name, and Last Name fields for user accounts in MyAccountPortlet are all vulnerable to a persistent XSS issue. Any user can mod...                                    cpe:2.3:a:liferay:liferay_portal:7.2.0:rc1:*:*:community:*:*:*               1                0                                                                                                                               [[liferay, liferay], [portal ce, portal ce], [7.1.0 through 7.2.1, 7.3.0]]                                                                                                                                  [[0.99989474, 0.999897], [0.9170859, 0.9623395], [0.9999494, 0.984421]]                                        [liferay, liferay]                                                                                                [portal ce, portal ce]                                                                                                                        [7.1.0 through 7.2.1, 7.3.0]                                                                      [0.99989474, 0.999897]                                                                        [0.9170859, 0.9623395]                                                                                [0.9999494, 0.984421]         [liferay]         [0.999897]                   [portal ce]         [0.9623395]                          1                              myweb_portal_office                              fujitsu
# 175    CVE-2021-39359     637814        gnome                                                        libgda            1.99.1  In GNOME libgda through 6.0.0, gda-web-provider.c does not enable TLS certificate verification on the SoupSessionSync objects it creates, leaving users vulnerable to network MITM attacks. NOTE: th...                                                       cpe:2.3:a:gnome:libgda:1.99.1:*:*:*:*:*:*:*               1                1                                                                                                                                                                    [[gnome], [libgda], [through 6.0.0,]]                                                                                                                                                                [[0.99990654], [0.99990153], [0.9999572]]                                                   [gnome]                                                                                                              [libgda]                                                                                                                                    [through 6.0.0,]                                                                                [0.99990654]                                                                                  [0.99990153]                                                                                          [0.9999572]           [gnome]       [0.99990654]                      [libgda]        [0.99990153]                          1                                           libgda                                gnome
# 176    CVE-2022-42188     194830     lavalite                                                      lavalite             9.0.0                                                                 In Lavalite 9.0.0, the XSRF-TOKEN cookie is vulnerable to path traversal attacks, enabling read access to arbitrary files on the server.                                                   cpe:2.3:a:lavalite:lavalite:9.0.0:*:*:*:*:*:*:*               1                1                                                                                                                                                                               [[lavalite], [], [9.0.0,]]                                                                                                                                                                          [[0.99910754], [], [0.9999101]]                                                [lavalite]                                                                                                                    []                                                                                                                                            [9.0.0,]                                                                                [0.99910754]                                                                                            []                                                                                          [0.9999101]        [lavalite]       [0.99910754]                            []                  []                          1
# 179  CVE-2018-1000603     510880      jenkins                                               openstack_cloud              2.23  A exposure of sensitive information vulnerability exists in Jenkins Openstack Cloud Plugin 2.35 and earlier in BootSource.java, InstancesToRun.java, JCloudsCleanupThread.java, JCloudsCloud.java, J...                                        cpe:2.3:a:jenkins:openstack_cloud:2.23:*:*:*:*:jenkins:*:*               1                0                                                                                                                             [[jenkins], [openstack cloud plugin, jenkins, jenkins,], [2.35 and earlier]]                                                                                                                                         [[0.92532605], [0.9830148, 0.70783067, 0.8572247], [0.99992514]]                                                 [jenkins]                                                                           [openstack cloud plugin, jenkins, jenkins,]                                                                                                                                  [2.35 and earlier]                                                                                [0.92532605]                                                            [0.9830148, 0.70783067, 0.8572247]                                                                                         [0.99992514]         [jenkins]       [0.92532605]      [openstack cloud plugin]         [0.9830148]                          1                          openstack_cloud_crowbar                                 suse
# 181    CVE-2024-20692     262580    microsoft                                               windows_10_1507  10.0.10240.19204                                                                                                                Microsoft Local Security Authority Subsystem Service Information Disclosure Vulnerability                            cpe:2.3:o:microsoft:windows_10_1507:10.0.10240.19204:*:*:*:*:*:arm64:*               1                0                                                                                                                                                                               [[microsoft], [local], []]                                                                                                                                                                          [[0.99987197], [0.6119774], []]                                               [microsoft]                                                                                                               [local]                                                                                                                                                  []                                                                                [0.99987197]                                                                                   [0.6119774]                                                                                                   []       [microsoft]       [0.99987197]                       [local]         [0.6119774]                          0                                        localizer                    localizer_project
# 186     CVE-2021-4310     647321   01-scripts                                              01-artikelsystem               NaN  A vulnerability was found in 01-Scripts 01-Artikelsystem. It has been classified as problematic. Affected is an unknown function of the file 01article.php. The manipulation of the argument $_SERVE...                                         cpe:2.3:a:01-scripts:01-artikelsystem:*:*:*:*:*:01acp:*:*               1                1                                                                                                                                                                [[01-scripts], [01-artikelsystem.], [to]]                                                                                                                                                                [[0.99991214], [0.99780434], [0.6396883]]                                              [01-scripts]                                                                                                   [01-artikelsystem.]                                                                                                                                                [to]                                                                                [0.99991214]                                                                                  [0.99780434]                                                                                          [0.6396883]      [01-scripts]       [0.99991214]           [01-artikelsystem.]        [0.99780434]                          0                                 01-artikelsystem                           01-scripts
# 188    CVE-2022-45544     204359       schlix                                                           cms           2.2.7-2  Insecure Permission vulnerability in Schlix Web Inc SCHLIX CMS 2.2.7-2 allows attacker to upload arbitrary files and execute arbitrary code via the tristao parameter. NOTE: this is disputed by the...                                                        cpe:2.3:a:schlix:cms:2.2.7-2:*:*:*:*:*:*:*               1                1                                                                                                                                                                      [[schlix], [schlix cms], [2.2.7-2]]                                                                                                                                                                 [[0.99219453], [0.9966818], [0.9999616]]                                                  [schlix]                                                                                                          [schlix cms]                                                                                                                                           [2.2.7-2]                                                                                [0.99219453]                                                                                   [0.9966818]                                                                                          [0.9999616]          [schlix]       [0.99219453]                  [schlix cms]         [0.9966818]                          0  social_share\,_social_login_and_social_comments                               heator

# %%
print(df_test['product_in_text'].sum())
df_test[(df_test['product_ner'].astype(str) != '[]') & 
        (df_test['product_in_text'] == 1)]
# Out:
# 114
#                cve_id  cpe_id_pk                   vendor                    product       version                                                                                                                                                                                                    descr                                                                   initial_cpe  vendor_in_text  product_in_text                                                                                                                                                                                                ners_list                                                                                                                                                                                              scores_list        vendor_ner                                                                                                                                                                                              product_ner                                                                                                                                                                                              version_ner         vendor_score_ner                                                                                                                                                                                        product_score_ner                                                                                                                                                                                        version_score_ner      dedup_vendor dedup_vendor_score                         dedup_product dedup_product_score  true_version_in_predicted                                                                     matched_db_product                    matched_db_vendor
# 0      CVE-2021-34085     628902               glensawyer                    mp3gain         1.3.4  Read access violation in the III_dequantize_sample function in mpglibDBL/layer3.c in mp3gain through 1.5.2-r2 allows remote attackers to cause a denial of service (application crash) or possibly h...                           cpe:2.3:a:glensawyer:mp3gain:1.3.4:beta:*:*:*:*:*:*               0                1                                                                                                                                                                      [[], [mp3gain], [through 1.5.2-r2]]                                                                                                                                                                         [[], [0.99991965], [0.99996096]]                []                                                                                                                                                                                                [mp3gain]                                                                                                                                                                                       [through 1.5.2-r2]                       []                                                                                                                                                                                             [0.99991965]                                                                                                                                                                                             [0.99996096]                []                 []                             [mp3gain]        [0.99991965]                          1                                                                                mp3gain                           glensawyer
# 6      CVE-2019-13183     689916                   flarum                     flarum         0.1.0                                                                                           Flarum before 0.1.0-beta.9 allows CSRF against all POST endpoints, as demonstrated by changing admin settings.                             cpe:2.3:a:flarum:flarum:0.1.0:beta8.1:*:*:*:*:*:*               1                1                                                                                                                                                                    [[], [flarum], [before 0.1.0-beta.9]]                                                                                                                                                                          [[], [0.9974808], [0.99994767]]                []                                                                                                                                                                                                 [flarum]                                                                                                                                                                                    [before 0.1.0-beta.9]                       []                                                                                                                                                                                              [0.9974808]                                                                                                                                                                                             [0.99994767]                []                 []                              [flarum]         [0.9974808]                          1                                                                                 flarum                               flarum
# 7      CVE-2018-15121     522169                    auth0                     aspnet             -  An issue was discovered in Auth0 auth0-aspnet and auth0-aspnet-owin. Affected packages do not use or validate the state parameter of the OAuth 2.0 and OpenID Connect protocols. This leaves applica...                                        cpe:2.3:a:auth0:aspnet:-:*:*:*:*:*:*:*               1                1                                                                                                                                                  [[auth0], [auth0-aspnet, oauth, openid connect], [2.0]]                                                                                                                                         [[0.99983096], [0.92818856, 0.9774277, 0.88269305], [0.9996136]]           [auth0]                                                                                                                                                                    [auth0-aspnet, oauth, openid connect]                                                                                                                                                                                                    [2.0]             [0.99983096]                                                                                                                                                                      [0.92818856, 0.9774277, 0.88269305]                                                                                                                                                                                              [0.9996136]           [auth0]       [0.99983096]                               [oauth]         [0.9774277]                          0                                                                                  oauth                            atlassian
# 8       CVE-2013-2175     549900                  haproxy                    haproxy        1.4.17  HAProxy 1.4 before 1.4.24 and 1.5 before 1.5-dev19, when configured to use hdr_ip or other "hdr_*" functions with a negative occurrence count, allows remote attackers to cause a denial of service ...                                cpe:2.3:a:haproxy:haproxy:1.4.17:*:*:*:*:*:*:*               1                1                                                                                                                                              [[], [haproxy], [1.4 before 1.4.24, 1.5 before 1.5-dev19,]]                                                                                                                                                                [[], [0.9999064], [0.9999666, 0.9999676]]                []                                                                                                                                                                                                [haproxy]                                                                                                                                                               [1.4 before 1.4.24, 1.5 before 1.5-dev19,]                       []                                                                                                                                                                                              [0.9999064]                                                                                                                                                                                   [0.9999666, 0.9999676]                []                 []                             [haproxy]         [0.9999064]                          0                                                                                haproxy                              netgate
# 9      CVE-2016-10714     422757                      zsh                        zsh         4.2.2                                                                                 In zsh before 5.3, an off-by-one error resulted in undersized buffers that were intended to support PATH_MAX characters.                                         cpe:2.3:a:zsh:zsh:4.2.2:*:*:*:*:*:*:*               1                1                                                                                                                                                                               [[], [zsh], [before 5.3,]]                                                                                                                                                                          [[], [0.9995414], [0.99995625]]                []                                                                                                                                                                                                    [zsh]                                                                                                                                                                                            [before 5.3,]                       []                                                                                                                                                                                              [0.9995414]                                                                                                                                                                                             [0.99995625]                []                 []                                 [zsh]         [0.9995414]                          1                                                                                    zsh                                  zsh
# 10      CVE-2023-4393     375964              liquidfiles                liquidfiles        1.6.23                         HTML and SMTP injections on the registration page of LiquidFiles versions 3.7.13 and below, allow an attacker to perform more advanced phishing attacks against an organization.                        cpe:2.3:a:liquidfiles:liquidfiles:1.6.23:*:*:*:*:*:*:*               1                1                                                                                                                                                                 [[], [liquidfiles], [3.7.13 and below,]]                                                                                                                                                                            [[], [0.99991], [0.83767396]]                []                                                                                                                                                                                            [liquidfiles]                                                                                                                                                                                      [3.7.13 and below,]                       []                                                                                                                                                                                                [0.99991]                                                                                                                                                                                             [0.83767396]                []                 []                         [liquidfiles]           [0.99991]                          0                                                                            liquidfiles                          liquidfiles
# 12      CVE-2022-3768     178195         wpsmartcontracts           wpsmartcontracts         1.2.2  The WPSmartContracts WordPress plugin before 1.3.12 does not properly sanitise and escape a parameter before using it in a SQL statement, leading to a SQL injection exploitable by users with a rol...       cpe:2.3:a:wpsmartcontracts:wpsmartcontracts:1.2.2:*:*:*:*:wordpress:*:*               1                1                                                                                                                                                     [[], [wpsmartcontracts, wordpress], [before 1.3.12]]                                                                                                                                                              [[], [0.97421944, 0.99314076], [0.9999514]]                []                                                                                                                                                                            [wpsmartcontracts, wordpress]                                                                                                                                                                                          [before 1.3.12]                       []                                                                                                                                                                                 [0.97421944, 0.99314076]                                                                                                                                                                                              [0.9999514]                []                 []                           [wordpress]        [0.99314076]                          1                                                                              wordpress                            wordpress
# 13      CVE-2014-4700     719860                   citrix                 xendesktop           4.0  Citrix XenDesktop 7.x, 5.x, and 4.x, when pooled random desktop groups is enabled and ShutdownDesktopsAfterUse is disabled, allows local guest users to gain access to another user's desktop via un...                                 cpe:2.3:a:citrix:xendesktop:4.0:*:*:*:*:*:*:*               1                1                                                                                                                                                             [[citrix], [xendesktop], [7.x,, 5.x,, 4.x,]]                                                                                                                                             [[0.999882], [0.9998907], [0.9999678, 0.9999691, 0.9999697]]          [citrix]                                                                                                                                                                                             [xendesktop]                                                                                                                                                                                       [7.x,, 5.x,, 4.x,]               [0.999882]                                                                                                                                                                                              [0.9998907]                                                                                                                                                                        [0.9999678, 0.9999691, 0.9999697]          [citrix]         [0.999882]                          [xendesktop]         [0.9998907]                          0                                                                             xendesktop                               citrix
# 14      CVE-2015-8076     582232                    cyrus                       imap         2.5.2  The index_urlfetch function in index.c in Cyrus IMAP 2.3.x before 2.3.19, 2.4.x before 2.4.18, 2.5.x before 2.5.4 allows remote attackers to obtain sensitive information or possibly have unspecifi...                                      cpe:2.3:a:cyrus:imap:2.5.2:*:*:*:*:*:*:*               1                1                                                                                                                     [[], [cyrus imap], [2.3.x before 2.3.19,, 2.4.x before 2.4.18,, 2.5.x before 2.5.4]]                                                                                                                                                    [[], [0.9998886], [0.9999668, 0.99996823, 0.9999669]]                []                                                                                                                                                                                             [cyrus imap]                                                                                                                                         [2.3.x before 2.3.19,, 2.4.x before 2.4.18,, 2.5.x before 2.5.4]                       []                                                                                                                                                                                              [0.9998886]                                                                                                                                                                       [0.9999668, 0.99996823, 0.9999669]                []                 []                          [cyrus imap]         [0.9998886]                          1                                                                             cyrus_imap                            cyrusimap
# 15     CVE-2019-14862     692470               knockoutjs                   knockout         1.2.1  There is a vulnerability in knockout before version 3.5.0-beta, where after escaping the context of the web application, the web application delivers data to its users along with other trusted dyn...                             cpe:2.3:a:knockoutjs:knockout:1.2.1:*:*:*:*:*:*:*               0                1                                                                                                                                                           [[], [knockout], [before version 3.5.0-beta,]]                                                                                                                                                                           [[], [0.9442648], [0.9837834]]                []                                                                                                                                                                                               [knockout]                                                                                                                                                                             [before version 3.5.0-beta,]                       []                                                                                                                                                                                              [0.9442648]                                                                                                                                                                                              [0.9837834]                []                 []                            [knockout]         [0.9442648]                          1                                                                               knockout                           knockoutjs
# 18     CVE-2021-26754     617056             wpdatatables               wpdatatables         2.2.3                                                          wpDataTables before 3.4.1 mishandles order direction for server-side tables, aka admin-ajax.php?action=get_wdtable order[0][dir] SQL injection.               cpe:2.3:a:wpdatatables:wpdatatables:2.2.3:*:*:*:*:wordpress:*:*               1                1                                                                                                                                                                     [[], [wpdatatables], [before 3.4.1]]                                                                                                                                                                            [[], [0.9999089], [0.999958]]                []                                                                                                                                                                                           [wpdatatables]                                                                                                                                                                                           [before 3.4.1]                       []                                                                                                                                                                                              [0.9999089]                                                                                                                                                                                               [0.999958]                []                 []                        [wpdatatables]         [0.9999089]                          1                                                                           wpdatatables                        tms-outsource
# 20     CVE-2023-52323     406933             pycryptodome               pycryptodome        3.15.0                                                                            PyCryptodome and pycryptodomex before 3.19.1 allow side-channel leakage for OAEP decryption, exploitable for a Manger attack.                 cpe:2.3:a:pycryptodome:pycryptodome:3.15.0:*:*:*:*:python:*:*               1                1                                                                                                                                                     [[], [pycryptodome, pycryptodomex], [before 3.19.1]]                                                                                                                                                               [[], [0.9999124, 0.99988425], [0.9999557]]                []                                                                                                                                                                            [pycryptodome, pycryptodomex]                                                                                                                                                                                          [before 3.19.1]                       []                                                                                                                                                                                  [0.9999124, 0.99988425]                                                                                                                                                                                              [0.9999557]                []                 []                        [pycryptodome]         [0.9999124]                          1                                                                           pycryptodome                         pycryptodome
# 21      CVE-2005-2556      54655                   mantis                     mantis        0.19.1  core/database_api.php in Mantis 0.19.0a1 through 1.0.0a3, with register_globals enabled, allows remote attackers to connect to internal databases by modifying the g_db_type variable and monitoring...                                  cpe:2.3:a:mantis:mantis:0.19.1:*:*:*:*:*:*:*               1                1                                                                                                                                                              [[], [mantis], [0.19.0a1 through 1.0.0a3,]]                                                                                                                                                                          [[], [0.99992085], [0.9999666]]                []                                                                                                                                                                                                 [mantis]                                                                                                                                                                              [0.19.0a1 through 1.0.0a3,]                       []                                                                                                                                                                                             [0.99992085]                                                                                                                                                                                              [0.9999666]                []                 []                              [mantis]        [0.99992085]                          0                                                                                 mantis                              jenkins
# 23      CVE-2023-6998     414164                  coolkit                    ewelink        4.13.1                           Improper privilege management vulnerability in CoolKit Technology eWeLink on Android and iOS allows application lockscreen bypass.This issue affects eWeLink before 5.2.0.\n\n                          cpe:2.3:a:coolkit:ewelink:4.13.1:*:*:*:*:android:*:*               1                1                                                                                                                                                         [[coolkit], [ewelink, ewelink], [before 5.2.0.]]                                                                                                                                                       [[0.9544912], [0.9998672, 0.9998958], [0.9999499]]         [coolkit]                                                                                                                                                                                       [ewelink, ewelink]                                                                                                                                                                                          [before 5.2.0.]              [0.9544912]                                                                                                                                                                                   [0.9998672, 0.9998958]                                                                                                                                                                                              [0.9999499]         [coolkit]        [0.9544912]                             [ewelink]         [0.9998958]                          1                                                                                ewelink                              coolkit
# 24      CVE-2015-9438     587317  display-widgets_project            display-widgets          1.23                                        The display-widgets plugin before 2.04 for WordPress has XSS via the wp-admin/admin-ajax.php?action=dw_show_widget id_base, widget_number, or instance parameter.  cpe:2.3:a:display-widgets_project:display-widgets:1.23:*:*:*:*:wordpress:*:*               0                1                                                                                                                                                                   [[], [display-widgets], [before 2.04]]                                                                                                                                                                           [[], [0.9999174], [0.9999537]]                []                                                                                                                                                                                        [display-widgets]                                                                                                                                                                                            [before 2.04]                       []                                                                                                                                                                                              [0.9999174]                                                                                                                                                                                              [0.9999537]                []                 []                     [display-widgets]         [0.9999174]                          1                                                                        display-widgets              display-widgets_project
# 25      CVE-2005-0064      50263                     xpdf                       xpdf         0.92d  Buffer overflow in the Decrypt::makeFileKey2 function in Decrypt.cc for xpdf 3.00 and earlier allows remote attackers to execute arbitrary code via a PDF file with a large /Encrypt /Length keyLeng...                                       cpe:2.3:a:xpdf:xpdf:0.92d:*:*:*:*:*:*:*               1                1                                                                                                                                                                         [[], [xpdf], [3.00 and earlier]]                                                                                                                                                                          [[], [0.47657466], [0.9998846]]                []                                                                                                                                                                                                   [xpdf]                                                                                                                                                                                       [3.00 and earlier]                       []                                                                                                                                                                                             [0.47657466]                                                                                                                                                                                              [0.9998846]                []                 []                                [xpdf]        [0.47657466]                          0                                                                                   xpdf                          glyphandcog
# 28      CVE-2020-7981     500979             rubygeocoder                   geocoder         1.2.0                                sql.rb in Geocoder before 1.6.1 allows Boolean-based SQL injection when within_bounding_box is used in conjunction with untrusted sw_lat, sw_lng, ne_lat, or ne_lng data.                           cpe:2.3:a:rubygeocoder:geocoder:1.2.0:*:*:*:*:*:*:*               0                1                                                                                                                                                                         [[], [geocoder], [before 1.6.1]]                                                                                                                                                                           [[], [0.9998869], [0.9999563]]                []                                                                                                                                                                                               [geocoder]                                                                                                                                                                                           [before 1.6.1]                       []                                                                                                                                                                                              [0.9998869]                                                                                                                                                                                              [0.9999563]                []                 []                            [geocoder]         [0.9998869]                          1                                                                               geocoder                         rubygeocoder
# 29      CVE-2021-4306     646807     terminal-kit_project               terminal-kit       0.14.10  A vulnerability classified as problematic has been found in cronvel terminal-kit up to 2.1.7. Affected is an unknown function. The manipulation leads to inefficient regular expression complexity. ...       cpe:2.3:a:terminal-kit_project:terminal-kit:0.14.10:*:*:*:*:node.js:*:*               0                1                                                                                                                                  [[cronvel], [terminal-kit], [up to 2.1.7., upgrading to version 2.1.8]]                                                                                                                                                     [[0.6862143], [0.8992645], [0.99991924, 0.99988186]]         [cronvel]                                                                                                                                                                                           [terminal-kit]                                                                                                                                                               [up to 2.1.7., upgrading to version 2.1.8]              [0.6862143]                                                                                                                                                                                              [0.8992645]                                                                                                                                                                                 [0.99991924, 0.99988186]         [cronvel]        [0.6862143]                        [terminal-kit]         [0.8992645]                          1                                                                           terminal-kit                 terminal-kit_project
# 32     CVE-2023-34104     351206  fast-xml-parser_project            fast-xml-parser        4.0.14  fast-xml-parser is an open source, pure javascript xml parser. fast-xml-parser allows special characters in entity names, which are not escaped or sanitized. Since the entity name is used for crea...  cpe:2.3:a:fast-xml-parser_project:fast-xml-parser:4.0.14:*:*:*:*:node.js:*:*               0                1                                                                                                                                                          [[], [fast-xml-parser, fast-xml-parser], [xml]]                                                                                                                                                                [[], [0.9999279, 0.9999051], [0.9982792]]                []                                                                                                                                                                       [fast-xml-parser, fast-xml-parser]                                                                                                                                                                                                    [xml]                       []                                                                                                                                                                                   [0.9999279, 0.9999051]                                                                                                                                                                                              [0.9982792]                []                 []                     [fast-xml-parser]         [0.9999279]                          0                                                                        fast-xml-parser              fast-xml-parser_project
# 35      CVE-2013-6440     559861                internet2                   opensaml         2.2.0  The (1) BasicParserPool, (2) StaticBasicParserPool, (3) XML Decrypter, and (4) SAML Decrypter in Shibboleth OpenSAML-Java before 2.6.1 set the expandEntityReferences property to true, which allows...                              cpe:2.3:a:internet2:opensaml:2.2.0:*:*:*:*:*:*:*               0                1                                                                                                                                                          [[shibboleth], [opensaml-java], [before 2.6.1]]                                                                                                                                                                 [[0.9998066], [0.99969757], [0.9999613]]      [shibboleth]                                                                                                                                                                                          [opensaml-java]                                                                                                                                                                                           [before 2.6.1]              [0.9998066]                                                                                                                                                                                             [0.99969757]                                                                                                                                                                                              [0.9999613]      [shibboleth]        [0.9998066]                       [opensaml-java]        [0.99969757]                          1                                                                          opensaml_java                           shibboleth
# 38      CVE-2016-2054     431307                    xymon                      xymon        4.3.20  Multiple buffer overflows in xymond/xymond.c in xymond in Xymon 4.1.x, 4.2.x, and 4.3.x before 4.3.25 allow remote attackers to execute arbitrary code or cause a denial of service (daemon crash) v...                                    cpe:2.3:a:xymon:xymon:4.3.20:*:*:*:*:*:*:*               1                1                                                                                                                                                     [[], [xymon], [4.1.x,, 4.2.x,, 4.3.x before 4.3.25]]                                                                                                                                                     [[], [0.9999044], [0.9999696, 0.9999697, 0.9999644]]                []                                                                                                                                                                                                  [xymon]                                                                                                                                                                    [4.1.x,, 4.2.x,, 4.3.x before 4.3.25]                       []                                                                                                                                                                                              [0.9999044]                                                                                                                                                                        [0.9999696, 0.9999697, 0.9999644]                []                 []                               [xymon]         [0.9999044]                          1                                                                                  xymon                                xymon
# 40      CVE-2014-1740     715763                   google                     chrome  34.0.1847.78  Multiple use-after-free vulnerabilities in net/websockets/websocket_job.cc in the WebSockets implementation in Google Chrome before 34.0.1847.137 allow remote attackers to cause a denial of servic...                            cpe:2.3:a:google:chrome:34.0.1847.78:*:*:*:*:*:*:*               1                1                                                                                                                                                             [[google], [chrome], [before 34.0.1847.137]]                                                                                                                                                                 [[0.9998888], [0.9999132], [0.99996156]]          [google]                                                                                                                                                                                                 [chrome]                                                                                                                                                                                   [before 34.0.1847.137]              [0.9998888]                                                                                                                                                                                              [0.9999132]                                                                                                                                                                                             [0.99996156]          [google]        [0.9998888]                              [chrome]         [0.9999132]                          0                                                                                 chrome                               google
# 41     CVE-2023-28110     328088                fit2cloud                       koko             -  Jumpserver is a popular open source bastion host, and Koko is a Jumpserver component that is the Go version of coco, refactoring coco's SSH/SFTP service and Web Terminal service. Prior to version ...                                     cpe:2.3:a:fit2cloud:koko:-:*:*:*:*:go:*:*               0                1                                                                                                                     [[], [jumpserver, koko, jumpserver, koko], [prior to version 2.28.8,, through koko]]                                                                                                                            [[], [0.99910516, 0.9882967, 0.99900985, 0.9902644], [0.9997096, 0.94393486]]                []                                                                                                                                                                     [jumpserver, koko, jumpserver, koko]                                                                                                                                                                 [prior to version 2.28.8,, through koko]                       []                                                                                                                                                           [0.99910516, 0.9882967, 0.99900985, 0.9902644]                                                                                                                                                                                  [0.9997096, 0.94393486]                []                 []                          [jumpserver]        [0.99910516]                          0                                                                             jumpserver                           jumpserver
# 45     CVE-2018-12491     518137                    phpok                      phpok       4.9.032  PHPOK 4.9.032 has an arbitrary file upload vulnerability in the import_f function in framework/admin/modulec_control.php, as demonstrated by uploading a .php file within a .php.zip archive, a simi...                                   cpe:2.3:a:phpok:phpok:4.9.032:*:*:*:*:*:*:*               1                1                                                                                                                                                                                 [[], [phpok], [4.9.032]]                                                                                                                                                                             [[], [0.999905], [0.999966]]                []                                                                                                                                                                                                  [phpok]                                                                                                                                                                                                [4.9.032]                       []                                                                                                                                                                                               [0.999905]                                                                                                                                                                                               [0.999966]                []                 []                               [phpok]          [0.999905]                          1                                                                                  phpok                                phpok
# ...
# 186     CVE-2021-4310     647321               01-scripts           01-artikelsystem           NaN  A vulnerability was found in 01-Scripts 01-Artikelsystem. It has been classified as problematic. Affected is an unknown function of the file 01article.php. The manipulation of the argument $_SERVE...                     cpe:2.3:a:01-scripts:01-artikelsystem:*:*:*:*:*:01acp:*:*               1                1                                                                                                                                                                [[01-scripts], [01-artikelsystem.], [to]]                                                                                                                                                                [[0.99991214], [0.99780434], [0.6396883]]      [01-scripts]                                                                                                                                                                                      [01-artikelsystem.]                                                                                                                                                                                                     [to]             [0.99991214]                                                                                                                                                                                             [0.99780434]                                                                                                                                                                                              [0.6396883]      [01-scripts]       [0.99991214]                   [01-artikelsystem.]        [0.99780434]                          0                                                                       01-artikelsystem                           01-scripts
# 188    CVE-2022-45544     204359                   schlix                        cms       2.2.7-2  Insecure Permission vulnerability in Schlix Web Inc SCHLIX CMS 2.2.7-2 allows attacker to upload arbitrary files and execute arbitrary code via the tristao parameter. NOTE: this is disputed by the...                                    cpe:2.3:a:schlix:cms:2.2.7-2:*:*:*:*:*:*:*               1                1                                                                                                                                                                      [[schlix], [schlix cms], [2.2.7-2]]                                                                                                                                                                 [[0.99219453], [0.9966818], [0.9999616]]          [schlix]                                                                                                                                                                                             [schlix cms]                                                                                                                                                                                                [2.2.7-2]             [0.99219453]                                                                                                                                                                                              [0.9966818]                                                                                                                                                                                              [0.9999616]          [schlix]       [0.99219453]                          [schlix cms]         [0.9966818]                          0                                        social_share\,_social_login_and_social_comments                               heator
# 189     CVE-2020-4038     490689                   prisma    graphql-playground-html         1.4.3  GraphQL Playground (graphql-playground-html NPM package) before version 1.6.22 have a severe XSS Reflection attack vulnerability. All unsanitized user input passed into renderPlaygroundPage() meth...            cpe:2.3:a:prisma:graphql-playground-html:1.4.3:*:*:*:*:node.js:*:*               0                1  [[graphql], [graphql-playground-html, graphql-playground-middleware-express, graphql-playground-middleware-koa, graphql-playground-middleware-lambda, graphql-playground-middleware-hapi], [before v...                                                              [[0.8477701], [0.9992661, 0.99859256, 0.999161, 0.9993229, 0.99947375], [0.999938, 0.9856011, 0.9995408, 0.99992627, 0.9999283, 0.9999337]]         [graphql]                            [graphql-playground-html, graphql-playground-middleware-express, graphql-playground-middleware-koa, graphql-playground-middleware-lambda, graphql-playground-middleware-hapi]                                                                                 [before version 1.6.22, 1.6.22., before version 1.7.16,, before version 1.6.15,, before version 1.7.17,, before 1.6.13.]              [0.8477701]                                                                                                                                                 [0.9992661, 0.99859256, 0.999161, 0.9993229, 0.99947375]                                                                                                                                       [0.999938, 0.9856011, 0.9995408, 0.99992627, 0.9999283, 0.9999337]         [graphql]        [0.8477701]  [graphql-playground-middleware-hapi]        [0.99947375]                          1                                                     graphql-playground-middleware-hapi                               prisma
# 190    CVE-2023-35163     354128                 gobalsky                       vega        0.33.1  Vega is a decentralized trading platform that allows pseudo-anonymous trading of derivatives on a blockchain. Prior to version 0.71.6, a vulnerability exists that allows a malicious validator to t...                                  cpe:2.3:a:gobalsky:vega:0.33.1:*:*:*:*:*:*:*               0                1                                                                                                                                              [[], [vega, vega, vega,, vega], [prior to version 0.71.6,]]                                                                                                                                       [[], [0.99370885, 0.8913145, 0.85312486, 0.9591649], [0.99977887]]                []                                                                                                                                                                                [vega, vega, vega,, vega]                                                                                                                                                                               [prior to version 0.71.6,]                       []                                                                                                                                                           [0.99370885, 0.8913145, 0.85312486, 0.9591649]                                                                                                                                                                                             [0.99977887]                []                 []                                [vega]        [0.99370885]                          0                                                                                   vega                         vega_project
# 192    CVE-2021-33176     627381               octavolabs                    vernemq         1.0.0  VerneMQ MQTT Broker versions prior to 1.12.0 are vulnerable to a denial of service attack as a result of excessive memory consumption due to the handling of untrusted inputs. These inputs cause th...                              cpe:2.3:a:octavolabs:vernemq:1.0.0:-:*:*:*:*:*:*               0                1                                                                                                                                                            [[vernemq], [mqtt broker], [prior to 1.12.0]]                                                                                                                                                               [[0.99925786], [0.99971294], [0.99991876]]         [vernemq]                                                                                                                                                                                            [mqtt broker]                                                                                                                                                                                        [prior to 1.12.0]             [0.99925786]                                                                                                                                                                                             [0.99971294]                                                                                                                                                                                             [0.99991876]         [vernemq]       [0.99925786]                         [mqtt broker]        [0.99971294]                          1                                                             small_footprint_cim_broker                       chris_buccella
# 193     CVE-2016-5876     437832                 owncloud                   owncloud         9.0.0                                           ownCloud server before 8.2.6 and 9.x before 9.0.3, when the gallery app is enabled, allows remote attackers to download arbitrary images via a direct request.                               cpe:2.3:a:owncloud:owncloud:9.0.0:*:*:*:*:*:*:*               1                1                                                                                                                                                      [[], [owncloud], [before 8.2.6, 9.x before 9.0.3,]]                                                                                                                                                                 [[], [0.99991], [0.99996156, 0.9999661]]                []                                                                                                                                                                                               [owncloud]                                                                                                                                                                        [before 8.2.6, 9.x before 9.0.3,]                       []                                                                                                                                                                                                [0.99991]                                                                                                                                                                                  [0.99996156, 0.9999661]                []                 []                            [owncloud]           [0.99991]                          0                                                                               owncloud                             owncloud
# 194    CVE-2021-24472     607645             qantumthemes                     onair2         3.9.3  The OnAir2 WordPress theme before 3.9.9.2 and QT KenthaRadio WordPress plugin before 2.0.2 have exposed proxy functionality to unauthenticated users, sending requests to this proxy functionality w...                     cpe:2.3:a:qantumthemes:onair2:3.9.3:*:*:*:*:wordpress:*:*               0                1                                                                                                                      [[onair2, qt], [wordpress, kentharadio, wordpress], [before 3.9.9.2, before 2.0.2]]                                                                                                                    [[0.73382086, 0.8601528], [0.9012168, 0.99422354, 0.9187399], [0.9999491, 0.9999509]]      [onair2, qt]                                                                                                                                                                      [wordpress, kentharadio, wordpress]                                                                                                                                                                           [before 3.9.9.2, before 2.0.2]  [0.73382086, 0.8601528]                                                                                                                                                                       [0.9012168, 0.99422354, 0.9187399]                                                                                                                                                                                   [0.9999491, 0.9999509]              [qt]        [0.8601528]                         [kentharadio]        [0.99422354]                          1                                                                            kentharadio                         qantumthemes
# 199    CVE-2021-21353     597916                    pugjs                        pug        0.15.4  Pug is an npm package which is a high-performance template engine. In pug before version 3.0.1, if a remote attacker was able to control the `pretty` option of the pug compiler, e.g. if you spread...                                cpe:2.3:a:pugjs:pug:0.15.4:*:*:*:*:node.js:*:*               0                1                                                                                                                                            [[], [pug, pug, pug, pug, pug, pug], [before version 3.0.1,]]                                                                                                                 [[], [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881], [0.9999499]]                []                                                                                                                                                                           [pug, pug, pug, pug, pug, pug]                                                                                                                                                                                  [before version 3.0.1,]                       []                                                                                                                                    [0.99846953, 0.99101406, 0.7614806, 0.95667714, 0.9470856, 0.9828881]                                                                                                                                                                                              [0.9999499]                []                 []                                 [pug]        [0.99846953]                          1                                                                                    pug                                pugjs

# %%
def extract_version(matched):
        if matched:
            version = matched.group('version')
            # Normalize separators (replace '-' with '.' if needed)
            version = version.replace('-', '.')
            return version
        return None

def classify_version_string(version_str):
    """
    Generate all versions for expressions containing 'before'.
    Handles two cases:
    1) "before X.Y.Z" - generates all versions up to X.Y.Z
    2) "A.B.x before A.B.C" - generates all patch versions A.B.0 to A.B.(C-1)
    """
    version_str = str.lower(version_str)



    # through, including
    group_name = 'through'
    group_words = ['through', 'earlier', '<=', 'prior', 'up to', 'up to, and including', 'up to and including', 'older']
    for group_wrd in group_words:
        if group_wrd in version_str:
            # More complicated multi version logic
            # '2.1 through 3.17'
            multi_version_pattern = r'(?P<version1>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)\s*' \
                        r'(?:through|earlier|prior|\<\=|up to)\s*' \
                        r'(?P<version2>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)'
            multi_match = re.search(multi_version_pattern, version_str, re.IGNORECASE)
            if multi_match:
                version1 = multi_match.group('version1')
                version2 = multi_match.group('version2')
                return [version1, version2], f'{group_name} multi-match'

            pattern = (
                r'(?P<version>[\dxX]+(?:[.-]\s*[\dxX]+)*)'  # Version with digits/x and separators
            )
            matched = re.search(pattern, version_str, re.IGNORECASE)
            return [extract_version(matched)], f'{group_name} group'

    # before, not including
    group_name = 'before'
    group_words = ['before', '<']
    for group_wrd in group_words:
        if group_wrd in version_str:
            # More complicated multi version logic
            # '4.2.x before 4.2.8'
            multi_version_pattern = r'(?P<version1>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)\s*' \
                        r'(?:before)\s*' \
                        r'(?P<version2>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)'
            multi_match = re.search(multi_version_pattern, version_str, re.IGNORECASE)
            if multi_match:
                version1 = multi_match.group('version1')
                version2 = multi_match.group('version2')
                return [version1, version2], f'{group_name} multi-match'

            # if simple logic
            pattern = (
                r'(?P<version>[\dxX]+(?:[.-]\s*[\dxX]+)*)'  # Version with digits/x and separators
            )
            matched = re.search(pattern, version_str, re.IGNORECASE)
            return [extract_version(matched)], f'{group_name} group'

    # after, including
    group_name = 'after'
    group_words = ['after', '>=']
    for group_wrd in group_words:
        if group_wrd in version_str:
            # More complicated multi version logic
            # '4.2.x before 4.2.8'
            multi_version_pattern = r'(?P<version1>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)\s*' \
                        r'(?:older|after|\>\=)\s*' \
                        r'(?P<version2>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)'
            multi_match = re.search(multi_version_pattern, version_str, re.IGNORECASE)
            if multi_match:
                version1 = multi_match.group('version1')
                version2 = multi_match.group('version2')
                return [version1, version2], f'{group_name} multi-match'

            # if simple logic
            pattern = (
                r'(?P<version>[\dxX]+(?:[.-]\s*[\dxX]+)*)'  # Version with digits/x and separators
            )
            matched = re.search(pattern, version_str, re.IGNORECASE)
            return [extract_version(matched)], f'{group_name} group'

    # between
    group_name = 'between'
    group_words = ['between', 'to', ' - ']
    for group_wrd in group_words:
        if group_wrd in version_str:
            # More complicated multi version logic
            # '4.2.x before 4.2.8'
            multi_version_pattern = r'(?P<version1>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)\s*' \
                        r'(?:between|to)\s*' \
                        r'(?P<version2>[\dxX]+(?:\s*[.-]\s*[\dxX]+)*)'
            multi_match = re.search(multi_version_pattern, version_str, re.IGNORECASE)
            if multi_match:
                version1 = multi_match.group('version1')
                version2 = multi_match.group('version2')
                return [version1, version2], f'{group_name} multi-match'

            # # if simple logic
            # pattern = (
            #     r'(?P<version>[\dxX]+(?:[.-]\s*[\dxX]+)\s*)'  # Version with digits/x and separators
            # )
            # matched = re.search(pattern, version_str, re.IGNORECASE)
            # return extract_version(matched), f'{group_name} group'



    pattern = (
        r'(?:v|version)?\s*'  # Optional 'v' or 'version'
        r'(?P<version>[\dxX]+(?:[.-]\s*[\dxX]+)*)'  # Version with digits/x and separators
    )
    matched = re.search(pattern, version_str, re.IGNORECASE)
    return [extract_version(matched)], 'other'

# %%
def parse_version(version_str):
    components = re.findall(r'\d+|x', version_str, re.IGNORECASE)
    parsed = []
    for c in components:
        if c.lower() == 'x':
            parsed.append('x')
        else:
            parsed.append(int(c))
    return parsed

# %%
generate_versions('2.5.1.5', 'before')
# Out:
# []

# %%
def generate_versions(versions, group_name, debug=False):
    if group_name == 'other':
        result = [versions[0]]
        version_other = parse_version(versions[0])
        while len(version_other) != 3:
            if len(version_other) > 3:
                result.append('.'.join([str(x) for x in version_other]))
                version_other.pop()
            elif len(version_other) < 3:
                result.append('.'.join([str(x) for x in version_other]))
                version_other.append(0)
        else:
            result.append('.'.join([str(x) for x in version_other]))
        # print(f'result: {result}')
        # print(f'other versions: {other_versions}')
        # result_merged = result + other_versions
        # print(f'joined: {result_merged}')
        return result
        # return versions
    group_type = group_name.split()[0].lower()

    if len(versions) == 1:
        if group_type == 'before':
            return generate_versions(['0.0.0', versions[0]], 'before multi-match', debug=debug)
        elif group_type == 'through':
            return generate_versions(['0.0.0', versions[0]], 'through multi-match', debug=debug)
        # here access DB and query max version?
        elif group_type == 'after':
            return generate_versions([versions[0], '20.0.0'], 'after multi-match', debug=debug)
        else:
            return []
    elif len(versions) >= 1:
        # for ['3.x', '3.1.1']
        # 3.x
        start = parse_version(versions[0])
        len_original_start = len(start)
        # 3.1.1
        end = parse_version(versions[1])
        len_original_end = len(end)
        # normalize versions
        while len(start) != 3:
            if len(start) > 3:
                start.pop()
            elif len(start) < 3:
                start.append(0)

        while len(end) != 3:
            if len(end) > 3:
                end.pop()
            elif len(end) < 3:
                end.append(0)

        possible_values = []
        if debug:
            print(f'start version: {start}, end version: {end}')
            print(f'len_original_end: {len_original_end}')
        for i in range(3):
            # print(f'possible values: {possible_values}')
            # 3
            start_comp = start[i]
            # 3
            end_comp = end[i]
            if debug:
                print(f'Start component: {start_comp}, End component: {end_comp}')

            if start_comp == 'x':
                # Надо как-то проверять, нужно ли генерировать такик большие числа версий
                if 'before' in group_type:
                    max_val = end_comp - 1 if isinstance(end_comp, int) else 99
                else:
                    max_val = end_comp if isinstance(end_comp, int) else 99
                possible_values.append(list(range(0, max_val + 1)))

                continue
            if isinstance(start_comp, int):
                if isinstance(end_comp, str) and end_comp.lower() == 'x':
                    end_comp = 99  # High maximum for 'x' in end
                if start_comp > end_comp:
                    return []
                if start_comp < end_comp:
                    if 'before' in group_type:
                        current_max = end_comp - 1
                    else:
                        current_max = end_comp
                    # possible_values.append(list(range(start_comp, current_max + 1)))
                    possible_values.append(list(range(start_comp, 10)))

                    # Allow any values for remaining components
                    for j in range(i + 1, 3):
                        possible_values.append(list(range(0, 100)))  # Arbitrary high limit
                    break
                else:
                    possible_values.append([start_comp])
            else:
                # print(f'possible values: {possible_values}')
                possible_values.append([0])


        if debug:
            print(f'possible values: {possible_values}')
        if 'x' not in end and 'x' not in start:
            generated_components = list(product(*possible_values))
            if debug:
                print(f'generated components: {generated_components[:10]}')
            generated_components_to_use = []
            for val in generated_components:
                if not (((val[0] == end[0]
                        and val[1] > end[1]) or
                        (val[0] == end[0]
                        and val[1] == end[1]
                        and val[2] > end[2]) or
                        val[0] > end[0])
                    or ((val[0] == start[0]
                         and val[1] < start[1]) or
                        (val[0] == start[0]
                         and val[1] == start[1]
                         and val[2] < start[2])) or
                        val[0] < start[0]):
                    generated_components_to_use.append(val)
            if debug:
                print(f'generated components to use: {generated_components_to_use[:10], generated_components_to_use[-10:]}')
            versions_list = ['.'.join(map(str, v)) for v in generated_components_to_use]

            # return versions_list
        else:
            generated_components = list(product(*possible_values))
            versions_list = ['.'.join(map(str, v)) for v in generated_components]
        if len_original_end == 2 or len_original_start == 2:
            versions_set = []
            for x in versions_list:
                versions_set.append(x.split('.')[:2])
            versions_set = set(['.'.join(y) for y in versions_set])
            # for x in versions_list:
            versions_list.extend(list(versions_set))
        if debug:
            print(versions_list[:10])
        return versions_list
    else:
        # print('last else')
        return []

# %%
r = []
d_vers = {}
cve_to_vers = {}
d = {}
for i, row in df_test.iterrows():
    possible_versions = []
    # print(i, row['version_ner'])
    for version_ner in row['version_ner']:
        # print(version_ner)
        preprocessed_ner = classify_version_string(version_ner)
        if preprocessed_ner[0][0] is None:
            continue
        # print(preprocessed_ner, end='\n'+'*'*50+'\n')
        generated_versions = generate_versions(*preprocessed_ner)
        possible_versions.extend(generated_versions)
    r.append(1 if row['version'] in possible_versions else 0)
    # d_vers[(row['version'], row['cve_id'])] = 
    cve_to_vers[row['cve_id']] = row['version']
    d[row['cve_id']] = possible_versions

# %%
# for i, row in df_test.iterrows():
#     possible_versions = []
#     # print(i, row['version_ner'])
#     for version_ner in row['version_ner']:
#         # print(version_ner)
#         preprocessed_ner = classify_version_string(version_ner)
#         print(row['version_ner'], preprocessed_ner)

# %%
df_test['true_version_in_predicted'] = r

# %%
sum(r)
# Out:
# 113

# %%
count_vendor = 0
count_product = 0
for i, row in df_test.iterrows():

    if row['dedup_vendor']:
        if (row['vendor'] == row['dedup_vendor'][0]
            or row['vendor'] == '_'.join(row['dedup_vendor'][0].split())):
            count_vendor += 1
    if row['dedup_product']:
        if (row['product'] == row['dedup_product'][0]
            or row['product'] == '_'.join(row['dedup_product'][0].split())):
            count_product += 1    
        else:
            print(row['product'], row['dedup_product'])
# Out:
# teamspeak3 ['teamspeak']
# open_source_security_information_management ['usm']
# manageengine_applications_manager ['applications manager']
# manageengine_o365_manager_plus ['java servlet']
# aspnet ['oauth']
# tagmin_control_center ['tagboard']
# wpsmartcontracts ['wordpress']
# imap ['cyrus imap']
# filezilla_client ['paramiko']
# video_conferencing_with_zoom ['zoom wordpress']
# contact_form_\&_lead_form_elementor_builder ['wordpress']
# yukassa_for_woocommerce ['woocommerce']
# awsui\/components-react ['react']
# opensaml ['opensaml-java']
# monitoring_software ['serverscheck monitoring software']
# koko ['jumpserver']
# ssh_\&_web_terminal ['addon-ssh']
# firefly_iii ['firefly']
# personal_video_collection_script ['mall personal video collection script']
# formidable_form_builder ['formidable forms wordpress']
# owasp_antisamy_.net ['antisamy']
# cling ['4thline cling']
# android ['stst']
# java_system_communications_express ['personal address book']
# mappress ['wordpress']
# updraftplus ['wordpress backup']
# dashboard.js ['stimulsoft']
# google_language_translator ['google-language-translator']
# amazon_ec2 ['ec2']
# nd_shortcodes ['nd shortcodes wordpress']
# snyk_cli ['snyk-gradle-plugin']
# terraform_provider ['terraform’s']
# secure_copy_content_protection_and_content_locking ['content locking']
# localization_client ['localization']
# librsvg ['libsvg']
# side_menu ['wordpress']
# restaurant_menu_-_food_ordering_system_-_table_reservation ['table reservation']
# pear_archive_tar ['pear']
# mpay24 ['mpay24 payment module']
# learnpress ['wordpress']
# manageengine_network_configuration_manager ['opmanager']
# tribiq_cms ['tribal tribiq cms']
# gdm ['display manager']
# capital_one_spark ['spark pay']
# ark ['kde ark']
# k-9_mail ['k9mail']
# network_admission_control_manager_and_server_system_software ['clean access']
# eventon-lite ['eventon']
# highcharts ['js']
# biteship ['biteship biteship:']
# engine ['docker engine']
# my_wish_list ['my-wish-list']
# simply_schedule_appointments ['wordpress']
# premium_addons ['addons']
# operations_bridge_manager ['java scripts']
# knowledgebuilder ['knowledgebuilder,']
# eightstore-lite ['zigcy-baby']
# webex_meetings_server_2.6_mr2_patch ['webex meetings']
# open-xchange_appsuite ['ox app suite']
# email_extension_template ['jenkins email']
# gradio ['`gradio`']
# woocommerce_pdf_invoices\,_packing_slips\,_delivery_notes_and_shipping_labels ['shipping labels']
# track_\&_trace ['trace']
# epolicy_orchestrator ['epolicy orchestrator agent']
# phoronix_test_suite ['phoronix-test-suite']
# liferay_portal ['portal ce']
# fltk ['fltk crate']
# openstack_cloud ['openstack cloud plugin']
# discover ['kde discover']
# windows_10_1507 ['local']
# auto_publish_for_google_my_business ['wp google my business auto publish wordpress']
# 01-artikelsystem ['01-artikelsystem.']
# cms ['schlix cms']
# graphql-playground-html ['graphql-playground-middleware-hapi']
# job_manager ['job-manager']
# vernemq ['mqtt broker']
# onair2 ['kentharadio']
# x_server ['x.org server.']

# %% [markdown]
# Это те, что сразу совпали. При этом часть названий продуктов, похожи, но не точно. Поэтому нужно использовать поиск по строкам.

# %%
print(count_vendor, count_product)
# Out:
# 42 93

# %%
product_ner = df_test['dedup_product'].astype(str).apply(lambda x: x.lstrip('[\'').rstrip(']\'')).values
vendor_ner = df_test['dedup_vendor'].astype(str).apply(lambda x: x.lstrip('[\'').rstrip(']\'')).values

# %%
sum([1 if v in product_ner else 0 for v in df_test['product'].tolist() ])
# Out:
# 73

# %%
sum([1 if v in vendor_ner else 0 for v in df_test['vendor'].tolist() ])
# Out:
# 46

# %%
df_all = get_df_from_bd('select * from cpes limit 10000000;')

# %%
unique_products = df_all['product'].unique()
unique_vendors = df_all['vendor'].unique()

# %%
get_lcs('job-manager', unique_products)
# Out:
# ('job_management_partner_1\\/it_desktop_management-manager', 11)

# %%
get_ratio('biteship', unique_products)
# Out:
# ('biteship', 1)

# %%
def get_ratio(ner_name, unique_entities):
    ratio_scores = []
    if ner_name in unique_entities:
        return ner_name, 1
    for ent in unique_entities:
        ratio_scores.append(ratio(ner_name, ent))
    if len(np.argwhere(ratio_scores == np.max(ratio_scores))) <= 1:
        return unique_entities[np.argmax(ratio_scores)], np.max(ratio_scores)
    else:
        candidates = unique_entities[np.argwhere(ratio_scores == np.max(ratio_scores))]
        len_of_query = len(ner_name)
        d = -1
        fit_cand = ''
        for cand in candidates:
            cand = cand[0]
            diff = abs(len_of_query - len(cand))
            # print(cand, d, diff)
            if d == -1:
                d = diff
                fit_cand = cand
            elif d > diff:
                d = diff
                fit_cand = cand
            else:
                continue
        return fit_cand, np.max(ratio_scores)

# %%
def get_lcs(ner_name, unique_entities):
    if ner_name in unique_entities:
        return ner_name, 1
    lcs_scores = np.array(pylcs.lcs_of_list(ner_name, unique_entities))
    if len(np.argwhere(lcs_scores == np.max(lcs_scores))) <= 1:
        return unique_entities[np.argmax(lcs_scores)], np.max(lcs_scores)
    else:
        candidates = unique_entities[np.argwhere(lcs_scores == np.max(lcs_scores))]
        len_of_query = len(ner_name)
        d = -1
        fit_cand = ''
        for cand in candidates:
            cand = cand[0]
            diff = abs(len_of_query - len(cand))
            print(cand, d, diff)
            if d == -1:
                d = diff
                fit_cand = cand
            elif d > diff:
                d = diff
                fit_cand = cand
            else:
                continue
        return fit_cand, np.max(lcs_scores)

# %%
(prod, score)= get_lcs('serverscheck monitoring software', unique_products)
print(prod, score)
df_all = get_df_from_bd(f"select * from cpes where product = '{prod}' limit 1;")
df_all
# Out:
# telepresence_video_communication_server_software -1 16
# zfs_storage_application_integration_engineering_software 16 24
# telepresence_video_communication_servers_software 16 17
# telepresence_video_communication_server_software 21
#    cpe_id_pk cpe_version part vendor                                           product version update edition sw_edition target_sw target_hw language other                                                                            initial_cpe
# 0     571804         2.3    a  cisco  telepresence_video_communication_server_software    x8.5    rc4                                                        cpe:2.3:a:cisco:telepresence_video_communication_server_software:x8.5:rc4:*:*:*:*:*:*

# %%
matched_db_product = []
matched_db_vendor = []
for pr in product_ner:
    if pr:
        print(f'Product NER: {pr}')
        ########################################################
        # (prod, score)= get_lcs_nonnorm(pr, unique_products)
        # print('Old')
        # print(f'Found product in DB: {prod}')
        # print(f'score: {score}')
        # print('Normed')
        ########################################################
        (prod, score)= get_lcs(pr, unique_products)
        print(f'Found product in DB: {prod}')
        print(f'score: {score}', end='\n\n')
        df_all = get_df_from_bd(f"select * from cpes where product = '{prod}' limit 1;")
        matched_db_vendor.append(df_all['vendor'].values[0])
        matched_db_product.append(df_all['product'].values[0])
    else:
        matched_db_product.append('')
        matched_db_vendor.append('')
# Out:
# Product NER: mp3gain
# Found product in DB: mp3gain
# score: 1
#
# Product NER: teamspeak
# Found product in DB: teamspeak
# score: 1
#
# Product NER: usm
# Found product in DB: usermin
# score: 3
#
# Product NER: applications manager
# Found product in DB: applications_manager
# score: 19
#
# Product NER: java servlet
# Found product in DB: java_communications_services_delegated_administrator
# score: 11
#
# Product NER: flarum
# Found product in DB: flarum
# score: 1
#
# Product NER: oauth
# Found product in DB: oauth
# score: 1
#
# Product NER: haproxy
# Found product in DB: haproxy
# score: 1
#
# Product NER: zsh
# Found product in DB: zsh
# score: 1
#
# Product NER: liquidfiles
# Found product in DB: liquidfiles
# score: 1
#
# Product NER: tagboard
# Found product in DB: tagboard
# score: 1
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: xendesktop
# Found product in DB: xendesktop
# score: 1
#
# Product NER: cyrus imap
# Found product in DB: cyrus_imap
# score: 9
#
# Product NER: knockout
# Found product in DB: knockout
# score: 1
#
# Product NER: paramiko
# Found product in DB: paramiko
# score: 1
#
# Product NER: wpdatatables
# Found product in DB: wpdatatables
# score: 1
#
# Product NER: wp email capture
# Found product in DB: wp_email_capture
# score: 14
#
# Product NER: pycryptodome
# Found product in DB: pycryptodome
# score: 1
#
# Product NER: mantis
# Found product in DB: mantis
# score: 1
#
# Product NER: zoom wordpress
# Found product in DB: zero_spam_for_wordpress
# score: 12
#
# Product NER: ewelink
# Found product in DB: ewelink
# score: 1
#
# Product NER: display-widgets
# Found product in DB: display-widgets
# score: 1
#
# Product NER: xpdf
# Found product in DB: xpdf
# score: 1
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: woocommerce
# Found product in DB: woocommerce
# score: 1
#
# Product NER: geocoder
# Found product in DB: geocoder
# score: 1
#
# Product NER: terminal-kit
# Found product in DB: terminal-kit
# score: 1
#
# Product NER: react
# Found product in DB: react
# score: 1
#
# Product NER: fast-xml-parser
# Found product in DB: fast-xml-parser
# score: 1
#
# Product NER: opensaml-java
# Found product in DB: opensaml_java
# score: 12
#
# Product NER: serverscheck monitoring software
# Found product in DB: telepresence_video_communication_server_software
# score: 21
#
# Product NER: xymon
# Found product in DB: xymon
# score: 1
#
# Product NER: quiz maker
# Found product in DB: quiz_maker
# score: 9
#
# Product NER: chrome
# Found product in DB: chrome
# score: 1
#
# Product NER: jumpserver
# Found product in DB: jumpserver
# score: 1
#
# Product NER: addon-ssh
# Found product in DB: sysaid_on-premises
# score: 7
#
# Product NER: firefly
# Found product in DB: firefly
# score: 1
#
# Product NER: phpok
# Found product in DB: phpok
# score: 1
#
# Product NER: mall personal video collection script
# Found product in DB: personal_video_collection_script
# score: 29
#
# Product NER: madwifi
# Found product in DB: madwifi
# score: 1
#
# Product NER: formidable forms wordpress
# Found product in DB: post_form_registration_form_profile_form_for_user_profiles_and_content_forms
# score: 19
#
# Product NER: openreplay
# Found product in DB: openreplay
# score: 1
#
# Product NER: browserify-sign
# Found product in DB: browserify-sign
# score: 1
#
# Product NER: antisamy
# Found product in DB: antisamy
# score: 1
#
# Product NER: bold page builder
# Found product in DB: bold_page_builder
# score: 15
#
# Product NER: 4thline cling
# Found product in DB: tivoli_netcool_security_manager
# score: 10
#
# Product NER: claroline
# Found product in DB: claroline
# score: 1
#
# Product NER: ntp
# Found product in DB: ntp
# score: 1
#
# Product NER: mwembed
# Found product in DB: mwembed
# score: 1
#
# Product NER: getgo download manager
# Found product in DB: getgo_download_manager
# score: 20
#
# Product NER: postie
# Found product in DB: postie
# score: 1
#
# Product NER: bolt
# Found product in DB: bolt
# score: 1
#
# Product NER: stst
# Found product in DB: mstest
# score: 4
#
# Product NER: personal address book
# Found product in DB: professional_home_page_tools_guestbook
# score: 15
#
# Product NER: duckduckgo
# Found product in DB: duckduckgo
# score: 1
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: cacti
# Found product in DB: cacti
# score: 1
#
# Product NER: wordpress backup
# Found product in DB: wordpress_backup_to_dropbox
# score: 15
#
# Product NER: stimulsoft
# Found product in DB: ons_15216_optical_add_drop_multiplexer_software
# score: 10
#
# Product NER: node-red
# Found product in DB: node-red
# score: 1
#
# Product NER: rios
# Found product in DB: rios
# score: 1
#
# Product NER: lvyecms
# Found product in DB: lvyecms
# score: 1
#
# Product NER: google-language-translator
# Found product in DB: google_language_translator
# score: 24
#
# Product NER: ec2
# Found product in DB: ec2
# score: 1
#
# Product NER: simple-markdown
# Found product in DB: simple-markdown
# score: 1
#
# Product NER: auto amazon links
# Found product in DB: auto_amazon_links
# score: 15
#
# Product NER: accordion
# Found product in DB: accordion
# score: 1
#
# Product NER: vpopmail
# Found product in DB: vpopmail
# score: 1
#
# Product NER: nd shortcodes wordpress
# Found product in DB: password_reset_with_code_for_wordpress_rest_api
# score: 17
#
# Product NER: snyk-gradle-plugin
# Found product in DB: snyk_gradle_cli
# score: 12
#
# Product NER: abuild
# Found product in DB: abuild
# score: 1
#
# Product NER: maradns
# Found product in DB: maradns
# score: 1
#
# Product NER: splunk
# Found product in DB: splunk
# score: 1
#
# Product NER: terraform’s
# Found product in DB: water_operations_for_waternamics
# score: 10
#
# Product NER: obsidian
# Found product in DB: obsidian
# score: 1
#
# Product NER: content locking
# Found product in DB: secure_copy_content_protection_and_content_locking
# score: 14
#
# Product NER: localization
# Found product in DB: localization_client
# score: 12
#
# Product NER: codemirror
# Found product in DB: codemirror
# score: 1
#
# Product NER: mailenable
# Found product in DB: mailenable
# score: 1
#
# Product NER: gitlab
# Found product in DB: gitlab
# score: 1
#
# Product NER: fnet
# Found product in DB: fnet
# score: 1
#
# Product NER: coldfusion
# Found product in DB: coldfusion
# score: 1
#
# Product NER: libsvg
# Found product in DB: librsvg
# score: 6
#
# Product NER: cubecart
# Found product in DB: cubecart
# score: 1
#
# Product NER: verdaccio
# Found product in DB: verdaccio
# score: 1
#
# Product NER: personalized woocommerce cart page
# Found product in DB: personalized_woocommerce_cart_page
# score: 31
#
# Product NER: org mode
# Found product in DB: org_mode
# score: 7
#
# Product NER: foogallery
# Found product in DB: foogallery
# score: 1
#
# Product NER: mathjs
# Found product in DB: mathjs
# score: 1
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: table reservation
# Found product in DB: food-order-and-table-reservation-system
# score: 16
#
# Product NER: pear
# Found product in DB: pear
# score: 1
#
# Product NER: mpay24 payment module
# Found product in DB: barzahlen_payment_module_php_sdk
# score: 14
#
# Product NER: iono
# Found product in DB: iono
# score: 1
#
# Product NER: php execution
# Found product in DB: php_execution
# score: 12
#
# Product NER: support core
# Found product in DB: support_core
# score: 11
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: opmanager
# Found product in DB: opmanager
# score: 1
#
# Product NER: tribal tribiq cms
# Found product in DB: financial_services_basel_regulatory_capital_basic
# score: 11
#
# Product NER: display manager
# Found product in DB: display_manager
# score: 14
#
# Product NER: easy testimonials
# Found product in DB: easy_testimonials
# score: 16
#
# Product NER: spark pay
# Found product in DB: sparkspace
# score: 7
#
# Product NER: kde ark
# Found product in DB: kde_frameworks
# score: 6
#
# Product NER: k9mail
# Found product in DB: k-9_mail
# score: 6
#
# Product NER: clean access
# Found product in DB: controlled_admin_access
# score: 11
#
# Product NER: eventon
# Found product in DB: eventon
# score: 1
#
# Product NER: js
# Found product in DB: njs
# score: 2
#
# Product NER: grapesjs
# Found product in DB: grapesjs
# score: 1
#
# Product NER: design review
# Found product in DB: design_review
# score: 12
#
# Product NER: creative cloud
# Found product in DB: creative_cloud
# score: 13
#
# Product NER: webgui
# Found product in DB: webgui
# score: 1
#
# Product NER: msmtp
# Found product in DB: msmtp
# score: 1
#
# Product NER: ovirt-hosted-engine-setup
# Found product in DB: ovirt-hosted-engine-setup
# score: 1
#
# Product NER: mxgraph
# Found product in DB: mxgraph
# score: 1
#
# Product NER: acf photo gallery field
# Found product in DB: acf_photo_gallery_field
# score: 20
#
# Product NER: syncthing
# Found product in DB: syncthing
# score: 1
#
# Product NER: boastmachine
# Found product in DB: boastmachine
# score: 1
#
# Product NER: easycms
# Found product in DB: easycms
# score: 1
#
# Product NER: locutus
# Found product in DB: locutus
# score: 1
#
# Product NER: biteship biteship:
# Found product in DB: hutscripts_php_website_script
# score: 12
#
# Product NER: docker engine
# Found product in DB: virtualized_packet_core-single_instance
# score: 11
#
# Product NER: my-wish-list
# Found product in DB: my_wish_list
# score: 10
#
# Product NER: select identity
# Found product in DB: select_identity
# score: 14
#
# Product NER: wordpress
# Found product in DB: wordpress
# score: 1
#
# Product NER: audiobookshelf
# Found product in DB: audiobookshelf
# score: 1
#
# Product NER: vortex library
# Found product in DB: vortex_library
# score: 13
#
# Product NER: addons
# Found product in DB: ebx_add-ons
# score: 6
#
# Product NER: java scripts
# Found product in DB: javascript_sdk
# score: 11
#
# Product NER: bbportals
# Found product in DB: bbportals
# score: 1
#
# Product NER: knowledgebuilder,
# Found product in DB: knowledgebuilder
# score: 16
#
# Product NER: bigtree cms
# Found product in DB: bigtree_cms
# score: 10
#
# Product NER: bridge
# Found product in DB: bridge
# score: 1
#
# Product NER: zigcy-baby
# Found product in DB: zigcy-baby
# score: 1
#
# Product NER: webex meetings
# Found product in DB: webex_meetings
# score: 13
#
# Product NER: ox app suite
# Found product in DB: ox_app_suite
# score: 10
#
# Product NER: jenkins email
# Found product in DB: jenkins-cloudformation-plugin
# score: 11
#
# Product NER: `gradio`
# Found product in DB: gradio
# score: 6
#
# Product NER: shipping labels
# Found product in DB: package_points_and_shipping_labels_for_woocommerce
# score: 14
#
# Product NER: exceljs
# Found product in DB: exceljs
# score: 1
#
# Product NER: console-io
# Found product in DB: console-io
# score: 1
#
# Product NER: casdoor
# Found product in DB: casdoor
# score: 1
#
# Product NER: empire server
# Found product in DB: empire_server
# score: 12
#
# Product NER: trace
# Found product in DB: ltrace
# score: 5
#
# Product NER: ajenti
# Found product in DB: ajenti
# score: 1
#
# Product NER: opengrok
# Found product in DB: opengrok
# score: 1
#
# Product NER: epolicy orchestrator agent
# Found product in DB: epolicy_orchestrator_agent
# score: 24
#
# Product NER: phoronix-test-suite
# Found product in DB: phoronix_test_suite
# score: 17
#
# Product NER: portal ce
# Found product in DB: myweb_portal_office
# score: 8
#
# Product NER: libgda
# Found product in DB: libgda
# score: 1
#
# Product NER: fltk crate
# Found product in DB: frontend_manager_for_woocommerce_along_with_bookings_subscription_listings_compatible
# score: 9
#
# Product NER: processor diagnostic tool
# Found product in DB: processor_diagnostic_tool
# score: 23
#
# Product NER: openstack cloud plugin
# Found product in DB: openstack_cloud_crowbar
# score: 14
#
# Product NER: kde discover
# Found product in DB: deep_discovery_analyzer
# score: 10
#
# Product NER: local
# Found product in DB: localizer
# score: 5
#
# Product NER: bundler
# Found product in DB: bundler
# score: 1
#
# Product NER: wp google my business auto publish wordpress
# Found product in DB: process_integration_\(pgp_module_-_business-to-business_add_on\)
# score: 21
#
# Product NER: pyrocms
# Found product in DB: pyrocms
# score: 1
#
# Product NER: php-fusion
# Found product in DB: php-fusion
# score: 1
#
# Product NER: 01-artikelsystem.
# Found product in DB: 01-artikelsystem
# score: 16
#
# Product NER: grub legacy
# Found product in DB: grub_legacy
# score: 10
#
# Product NER: schlix cms
# Found product in DB: social_share\,_social_login_and_social_comments
# score: 8
#
# Product NER: graphql-playground-middleware-hapi
# Found product in DB: graphql-playground-middleware-hapi
# score: 1
#
# Product NER: vega
# Found product in DB: vega
# score: 1
#
# Product NER: job-manager
# Found product in DB: job_management_partner_1\/it_desktop_management-manager
# score: 11
#
# Product NER: mqtt broker
# Found product in DB: small_footprint_cim_broker
# score: 9
#
# Product NER: owncloud
# Found product in DB: owncloud
# score: 1
#
# Product NER: kentharadio
# Found product in DB: kentharadio
# score: 1
#
# Product NER: x.org server.
# Found product in DB: x.org-xserver
# score: 11
#
# Product NER: responsive poll
# Found product in DB: responsive_poll
# score: 14
#
# Product NER: pug
# Found product in DB: pug
# score: 1

# %%
product_ner
# Out:
# array(['mp3gain', 'teamspeak', 'usm', 'applications manager',
#        'java servlet', '', 'flarum', 'oauth', 'haproxy', 'zsh',
#        'liquidfiles', 'tagboard', 'wordpress', 'xendesktop', 'cyrus imap',
#        'knockout', '', 'paramiko', 'wpdatatables', 'wp email capture',
#        'pycryptodome', 'mantis', 'zoom wordpress', 'ewelink',
#        'display-widgets', 'xpdf', 'wordpress', 'woocommerce', 'geocoder',
#        'terminal-kit', '', 'react', 'fast-xml-parser', '', '',
#        'opensaml-java', '', 'serverscheck monitoring software', 'xymon',
#        'quiz maker', 'chrome', 'jumpserver', 'addon-ssh', '', 'firefly',
#        'phpok', 'mall personal video collection script', 'madwifi',
#        'formidable forms wordpress', 'openreplay', 'browserify-sign',
#        'antisamy', '', '', 'bold page builder', '4thline cling',
#        'claroline', 'ntp', 'mwembed', 'getgo download manager', 'postie',
#        '', 'bolt', 'stst', '', '', '', '', '', '', '',
#        'personal address book', 'duckduckgo', 'wordpress', 'cacti',
#        'wordpress backup', 'stimulsoft', 'node-red', 'rios', 'lvyecms',
#        '', 'google-language-translator', 'ec2', 'simple-markdown',
#        'auto amazon links', 'accordion', 'vpopmail', '',
#        'nd shortcodes wordpress', 'snyk-gradle-plugin', 'abuild',
#        'maradns', 'splunk', 'terraform’s', 'obsidian', 'content locking',
#        'localization', 'codemirror', 'mailenable', 'gitlab', 'fnet',
#        'coldfusion', 'libsvg', 'cubecart', 'verdaccio',
#        'personalized woocommerce cart page', 'org mode', 'foogallery',
#        'mathjs', 'wordpress', '', 'table reservation', 'pear',
#        'mpay24 payment module', 'iono', 'php execution', 'support core',
#        'wordpress', 'opmanager', 'tribal tribiq cms', 'display manager',
#        'easy testimonials', 'spark pay', 'kde ark', 'k9mail',
#        'clean access', 'eventon', 'js', 'grapesjs', 'design review',
#        'creative cloud', 'webgui', 'msmtp', 'ovirt-hosted-engine-setup',
#        'mxgraph', 'acf photo gallery field', 'syncthing', 'boastmachine',
#        'easycms', 'locutus', 'biteship biteship:', '', 'docker engine',
#        '', 'my-wish-list', 'select identity', 'wordpress',
#        'audiobookshelf', 'vortex library', 'addons', 'java scripts',
#        'bbportals', 'knowledgebuilder,', '', 'bigtree cms', '', '',
#        'bridge', 'zigcy-baby', 'webex meetings', '', 'ox app suite',
#        'jenkins email', '`gradio`', 'shipping labels', 'exceljs',
#        'console-io', 'casdoor', 'empire server', 'trace', 'ajenti',
#        'opengrok', 'epolicy orchestrator agent', 'phoronix-test-suite',
#        'portal ce', 'libgda', '', 'fltk crate',
#        'processor diagnostic tool', 'openstack cloud plugin',
#        'kde discover', 'local', 'bundler',
#        'wp google my business auto publish wordpress', 'pyrocms',
#        'php-fusion', '01-artikelsystem.', 'grub legacy', 'schlix cms',
#        'graphql-playground-middleware-hapi', 'vega', 'job-manager',
#        'mqtt broker', 'owncloud', 'kentharadio', 'x.org server.',
#        'responsive poll', '', '', 'pug'], dtype=object)

# %%
matched_db_product_lev = []
matched_db_vendor_lev = []
score_lev = []
for pr in tqdm(product_ner):
    if pr:
        print(f'Product NER: {pr}')
        ########################################################
        # (prod, score)= get_lcs_nonnorm(pr, unique_products)
        # print('Old')
        # print(f'Found product in DB: {prod}')
        # print(f'score: {score}')
        # print('Normed')
        ########################################################
        (prod, score)= get_ratio(pr, unique_products)
        print(f'Found product in DB: {prod}')
        print(f'score: {score}', end='\n\n')
        df_all = get_df_from_bd(f"select * from cpes where product = '{prod}' limit 1;")
        matched_db_product_lev.append(df_all['product'].values[0])
        matched_db_vendor_lev.append(df_all['vendor'].values[0])
        score_lev.append(score)
        
    else:
        matched_db_product_lev.append('')
        matched_db_vendor_lev.append('')
        score_lev.append(0)

# %%
df_test[['cve_id', 'product', 'matched_db_product', 'version']].replace(columns={'product': ''})
# Out:
#               cve_id                                          product                                                                       matched_db_product      version
# 0      CVE-2023-0878                                             nuxt                                                              cosminexus_portal_framework        1.0.0
# 1      CVE-2008-0444                                             elog                                                                       electronic_logbook        2.2.0
# 2     CVE-2020-14518                                      dreammapper                                                                              dreammapper       2.17.1
# 3     CVE-2022-27858                                     activity_log        the_university_of_cambridge_web_authentication_system_apache_authentication_agent        2.2.8
# 4      CVE-2022-4725                     aws_software_development_kit                                                                             drawings_sdk        2.2.4
# 5     CVE-2021-32691                              data-connector-rock            woocommerce_pdf_invoices\,_packing_slips\,_delivery_notes_and_shipping_labels        1.2.5
# 6      CVE-2016-4572                                              cdh                                                                             cloudera_cdh        5.5.1
# 7     CVE-2023-31441                                  advisor_network                                              communications_unified_inventory_management        2.2.0
# 8     CVE-2023-42261                        mobile_security_framework                                                                mobile_security_framework      0.9.4.1
# 9     CVE-2022-36532                                         bolt_cms                                                                                 bolt_cms        3.0.2
# 10     CVE-2023-5654                                   react-devtools                                                   openshift_developer_tools_and_services       4.10.4
# 11     CVE-2005-4194           sights_n_sounds_streaming_media_server                                                   sights_n_sounds_streaming_media_server          NaN
# 12    CVE-2023-35094                          wp_matterport_shortcode                                                                  wp_matterport_shortcode        1.7.1
# 13     CVE-2014-7851                                     ovirt-engine                                                                                    ovirt          3.3
# 14     CVE-2018-5429                            jasperreports_library                                                                            jasperreports        6.3.2
# 15     CVE-2004-0431                                        quicktime                                                                                quicktime          6.5
# 16     CVE-2023-0166                   product_slider_for_woocommerce                                                                       gs_products_slider      1.12.16
# 17    CVE-2017-12976                                        git-annex                                                                                git-annex   6.20160211
# 18    CVE-2021-21423                                           projen                                                                         github-workflows       0.15.3
# 19     CVE-2021-3765                                        validator                                                                                                3.19.1
# 20    CVE-2019-11504                                          zotonic                                                                                  zotonic       0.24.1
# 21    CVE-2023-25975                                        etsy_shop                                                                       websphere_deployer         0.11
# 22    CVE-2022-23993                                          pfsense                                                                                  pfsense        2.3.0
# 23  CVE-2018-1000831                                         k-9_mail                                                                                 k-9_mail        5.200
# 24     CVE-2017-1207                                  integration_bus                                                                 websphere_message_broker        9.0.0
# 25     CVE-2017-1723                          qradar_network_insights                                                                                                 7.2.8
# 26     CVE-2015-8360                                           bamboo                                                                                   bamboo        2.5.5
# 27     CVE-2015-3933                                         genixcms                                                                                 genixcms        0.0.3
# 28     CVE-2015-1913                          rational_test_workbench                                                                  rational_test_workbench      8.0.1.4
# 29    CVE-2022-36296                                     activedemand                                                                             activedemand       0.1.64
# 30    CVE-2021-43009                                            opmon                                                                                    opmon          9.9
# 31    CVE-2023-26517                           dashboard_widget_suite                                                                   dashboard_widget_suite          1.5
# 32    CVE-2019-19919                                    handlebars.js                                                                                                 4.0.3
# 33    CVE-2017-11348                                   octopus_server                                                                           octopus_deploy       3.2.20
# 34    CVE-2022-24124                                          casdoor                                                                                  casdoor        1.7.2
# 35     CVE-2023-1554                            quick_paypal_payments                                                                    quick_paypal_payments        5.7.4
# 36     CVE-2023-0230                     vk_all_in_one_expansion_unit                   electronic_reception_and_examination_of_application_for_radio_licenses        3.4.0
# 37     CVE-2016-9132                                            botan                                                                                    botan       1.9.13
# 38     CVE-2022-1453                                        rsvpmaker                                                                                rsvpmaker        7.3.2
# 39    CVE-2021-42715                                      stb_image.h                                                                                                  2.17
# 40     CVE-2017-6198                                        sandstorm                                                                                sandstorm         0.78
# 41     CVE-2023-0479  print_invoice_\&_delivery_notes_for_woocommerce                                                                              woocommerce        3.3.1
# 42    CVE-2017-16067                                      node-opencv                                                                              node-opencv        0.3.1
# 43    CVE-2023-32743                                      automatewoo                                                                      automated_solutions        5.0.2
# 44    CVE-2023-52216                       js_\&_css_script_optimizer                                                                                                 0.1.4
# 45    CVE-2024-23820                                          openfga                                                                                                1.3.10
# 46     CVE-2013-5829                                              jdk                                                                                  java_se        1.5.0
# 47     CVE-2022-1323                                            discy                                                                                wordpress          4.4
# 48    CVE-2023-24998                               commons_fileupload                                                                            file_uploader        1.2.2
# 49     CVE-2013-4818                                icewall_sso_agent                                                                              icewall_sso         10.0
# 50    CVE-2022-24071                                            whale                                                                            whale_browser        1.9.1
# 51    CVE-2019-15054                                         mailbird                                                                                 mailbird      2.6.0.0
# 52    CVE-2023-49799                                   nuxt_api_party                                                                           nuxt_api_party       0.16.1
# 53    CVE-2019-16752            private_instant_verified_transactions                                                                                     dash        0.8.2
# 54     CVE-2016-1265                                      junos_space                                                                                                     -
# 55     CVE-2012-2130                                         polarssl                                                                                 polarssl        1.1.0
# 56     CVE-2012-4524                                        xlockmore                                                                                xlockmore          3.0
# 57    CVE-2023-28864                                chef_infra_server                                                                        chef_infra_server     12.17.64
# 58     CVE-2006-3572                                            papoo                                                                                    papoo        3.0.0
# 59     CVE-2015-4345                             restful_web_services                                                                     restful_web_services      7.x-1.2
# 60    CVE-2023-41940                                              tap                                                            jenkins-cloudformation-plugin        2.0.1
# 61     CVE-2014-1740                                           chrome                                                                                   chrome  34.0.1847.5
# 62    CVE-2022-23496                   yet_another_useragent_analyzer                                                                                                 7.5.0
# 63     CVE-2016-2537                                 is_my_json_valid                                                                         is-my-json-valid        1.0.0
# 64  CVE-2018-1000140                                          librelp                                                                                  rsyslog       1.2.11
# 65    CVE-2022-40704                              phoronix_test_suite                                                                                                10.8.3
# 66    CVE-2021-33485                                          control  four_mountain_torrent_disaster_prevention\,_control_monitoring_and_early_warning_system          NaN
# 67    CVE-2023-37474                                        copyparty                                                                                                1.3.13
# 68    CVE-2018-10916                                             lftp                                                                                     lftp       4.0.10
# 69     CVE-2014-2949                                 arx_data_manager                                                                         arx_data_manager        3.1.0
# 70    CVE-2023-43256                                 gladys_assistant                                                                                assistant       4.16.0
# 71     CVE-2009-3941                                             mpop                                                                                     mpop        0.1.0
# 72     CVE-2020-1977                        expedition_migration_tool                                                                expedition_migration_tool       1.1.10
# 73     CVE-2004-0247                                    chaser_client                                                                                   chaser          1.5
# 74    CVE-2021-29642                                          gistpad                                                                                  gistpad       0.0.12
# 75     CVE-2020-8034                                           gollem                                                                                   gollem        3.0.3
# 76     CVE-2023-0100        business_intelligence_and_reporting_tools                                                  emc_solutions_enabler_virtual_appliance        4.4.1
# 77    CVE-2022-22540                netweaver_application_server_abap                                                                        netweaver_as_abap          701
# 78    CVE-2020-28269                                            field                                                                                                 1.0.0
# 79    CVE-2022-24785                                           moment                                                                          mediaelement.js       2.29.0
# 80     CVE-2018-8097                                              eve                                                      cups_easy_\(purchase_\&_inventory\)        0.0.7
# 81     CVE-2022-2432                    ecwid_ecommerce_shopping_cart                                                                  ecommerce_shopping_cart        2.2.1
# 82    CVE-2023-43583                   video_software_development_kit                                                         data_theorem_mobile_app_security      5.15.10
# 83    CVE-2018-15664                                           docker                                                                                   docker   17.07.0-ce
# 84    CVE-2022-22154                                            junos                                                                                    junos         18.3
# 85     CVE-2023-0502                                          wp_news                                                                  japanese_word_processor        1.1.3
# 86     CVE-2001-1226                                          adcycle                                                                                  adcycle         1.17
# 87    CVE-2019-20478                                      ruamel.yaml                                                                              ruamel.yaml      0.13.10
# 88     CVE-2013-1636                                          civicrm                                                                         pretty_link_lite        3.3.0
# 89    CVE-2019-10340                                           docker                                                                jenkins_operations_center        1.1.6
# 90     CVE-2015-3451                                       xml-libxml                                                                                                2.0002
# 91    CVE-2020-27507                                         kamailio                                                                                     spip        5.1.1
# 92     CVE-2023-0772                                     optinmonster                                                                            popup_builder        2.6.1
# 93    CVE-2023-29014                                goobi_viewer_core                                                                        goobi_viewer_core      22.03.1
# 94    CVE-2022-24441                                    snyk_security                                                                                 snyk_cli       2.4.46
# 95     CVE-2023-4827                                         filester                                                                         file_manager_pro        1.5.1
# 96    CVE-2021-34628                               admin_custom_login          contact_form\,_survey_\&_popup_form_plugin_for_wordpress_-_arforms_form_builder        2.4.2
# 97    CVE-2017-16083                               node-simple-router                                                                       node-simple-router      0.9.1-3
# 98     CVE-2017-5869                                            nuxeo                                                           application_extension_platform          6.0
# 99     CVE-2014-4758                     websphere_application_server                                                                 business_process_manager      7.2.0.1

# %%
df_test['matched_db_product'] = matched_db_product
df_test['matched_db_vendor'] = matched_db_vendor
df_test['matched_db_product_lev'] = matched_db_product_lev
df_test['matched_db_vendor_lev'] = matched_db_vendor_lev
df_test['score_lev'] = score_lev

# %%
fin = df_test[(df_test['matched_db_product'] == df_test['product']) & 
        (df_test['matched_db_vendor'] == df_test['vendor']) & 
        (df_test['true_version_in_predicted'] == 1)]
fin
# Out:
#               cve_id  cpe_id_pk            vendor                    product version                                                                                                                                                                                                    descr                                                                   initial_cpe                                                                                                       ners_list                                                      scores_list   vendor_ner                                                                         product_ner                           version_ner vendor_score_ner                   product_score_ner        version_score_ner dedup_vendor dedup_vendor_score                     dedup_product dedup_product_score         matched_db_product matched_db_vendor  true_version_in_predicted
# 7     CVE-2023-31441     341885              ncia            advisor_network   2.2.0  In NATO Communications and Information Agency anet (aka Advisor Network) through 3.3.0, an attacker can provide a crafted JSON file to sanitizeJson and cause an exception. This is related to the U...                            cpe:2.3:a:ncia:advisor_network:2.2.0:*:*:*:*:*:*:*                                                                  [[nato], [advisor network)], [through 3.3.0,]]                          [[0.98350936], [0.7389296], [0.999821]]       [nato]                                                                  [advisor network)]                      [through 3.3.0,]     [0.98350936]                         [0.7389296]               [0.999821]       [nato]       [0.98350936]                [advisor network)]         [0.7389296]            advisor_network              ncia                          1
# 12    CVE-2023-35094     353966           mpembed    wp_matterport_shortcode   1.7.1                                                     Auth. (contributor+) Stored Cross-Site Scripting (XSS) vulnerability in Julien Berthelot / MPEmbed WP Matterport Shortcode plugin <= 2.1.4 versions.         cpe:2.3:a:mpembed:wp_matterport_shortcode:1.7.1:*:*:*:*:wordpress:*:*                                                              [[], [wp matterport shortcode plugin], [<= 2.1.4]]                                  [[], [0.8236863], [0.82940006]]           []                                                    [wp matterport shortcode plugin]                            [<= 2.1.4]               []                         [0.8236863]             [0.82940006]           []                 []  [wp matterport shortcode plugin]         [0.8236863]    wp_matterport_shortcode           mpembed                          1
# 26     CVE-2015-8360     582917         atlassian                     bamboo   2.5.5                            An unspecified resource in Atlassian Bamboo before 5.9.9 and 5.10.x before 5.10.0 allows remote attackers to execute arbitrary Java code via serialized data to the JMS port.                                cpe:2.3:a:atlassian:bamboo:2.5.5:*:*:*:*:*:*:*                                                   [[atlassian], [bamboo], [before 5.9.9, 5.10.x before 5.10.0]]             [[0.9997923], [0.99958223], [0.99993604, 0.9999495]]  [atlassian]                                                                            [bamboo]  [before 5.9.9, 5.10.x before 5.10.0]      [0.9997923]                        [0.99958223]  [0.99993604, 0.9999495]  [atlassian]        [0.9997923]                          [bamboo]        [0.99958223]                     bamboo         atlassian                          1
# 30    CVE-2021-43009     646632        opservices                      opmon     9.9                                                                          A Cross Site Scripting (XSS) vulnerability exists in OpServices OpMon through 9.11 via the search parameter in the request URL.                                  cpe:2.3:a:opservices:opmon:9.9:*:*:*:*:*:*:*                                                                                   [[], [opmon], [through 9.11]]                                   [[], [0.9972307], [0.9998847]]           []                                                                             [opmon]                        [through 9.11]               []                         [0.9972307]              [0.9998847]           []                 []                           [opmon]         [0.9972307]                      opmon        opservices                          1
# 34    CVE-2022-24124     114598            casbin                    casdoor   1.7.2                                            The query API in Casdoor before 1.13.1 has a SQL injection vulnerability related to the field and value parameters, as demonstrated by api/get-organizations.                                  cpe:2.3:a:casbin:casdoor:1.7.2:*:*:*:*:*:*:*                                                                                [[], [casdoor], [before 1.13.1]]                                   [[], [0.9969404], [0.9999317]]           []                                                                           [casdoor]                       [before 1.13.1]               []                         [0.9969404]              [0.9999317]           []                 []                         [casdoor]         [0.9969404]                    casdoor            casbin                          1
# 35     CVE-2023-1554     298377  fullworksplugins      quick_paypal_payments   5.7.4  The Quick Paypal Payments WordPress plugin before 5.7.26.4 does not sanitise and escape some of its settings, which could allow high privilege users such as admin to perform Stored Cross-Site Scri...  cpe:2.3:a:fullworksplugins:quick_paypal_payments:5.7.4:*:*:*:*:wordpress:*:*                                                     [[], [quick paypal payments, wordpress], [before 5.7.26.4]]                         [[], [0.9503791, 0.8185743], [0.999895]]           []                                                  [quick paypal payments, wordpress]                     [before 5.7.26.4]               []              [0.9503791, 0.8185743]               [0.999895]           []                 []           [quick paypal payments]         [0.9503791]      quick_paypal_payments  fullworksplugins                          1
# 37     CVE-2016-9132     443587     botan_project                      botan  1.9.13  In Botan 1.8.0 through 1.11.33, when decoding BER data an integer overflow could occur, which would cause an incorrect length field to be computed. Some API callers may use the returned (incorrect...                            cpe:2.3:a:botan_project:botan:1.9.13:*:*:*:*:*:*:*                                                                         [[], [botan], [1.8.0 through 1.11.33,]]                                   [[], [0.9931213], [0.9999437]]           []                                                                             [botan]              [1.8.0 through 1.11.33,]               []                         [0.9931213]              [0.9999437]           []                 []                           [botan]         [0.9931213]                      botan     botan_project                          1
# 48    CVE-2023-24998     315104            apache         commons_fileupload   1.2.2  Apache Commons FileUpload before 1.5 does not limit the number of request parts to be processed resulting in the possibility of an attacker triggering a DoS with a malicious upload or series of up...                       cpe:2.3:a:apache:commons_fileupload:1.2.2:*:*:*:*:*:*:*                                                                  [[apache], [commons fileupload], [before 1.5]]                           [[0.9957885], [0.659995], [0.9999245]]     [apache]                                                                [commons fileupload]                          [before 1.5]      [0.9957885]                          [0.659995]              [0.9999245]     [apache]        [0.9957885]              [commons fileupload]          [0.659995]         commons_fileupload            apache                          1
# 50    CVE-2022-24071     114353         navercorp                      whale   1.9.1                                     A Built-in extension in Whale browser before 3.12.129.46 allows attackers to compromise the rendering process which could lead to controlling browser internal APIs.                         cpe:2.3:a:navercorp:whale:1.9.1:*:*:*:*:iphone_os:*:*                                                                             [[], [whale], [before 3.12.129.46]]                                   [[], [0.6959183], [0.9998584]]           []                                                                             [whale]                  [before 3.12.129.46]               []                         [0.6959183]              [0.9998584]           []                 []                           [whale]         [0.6959183]                      whale         navercorp                          1
# 56     CVE-2012-4524     251986        sillycycle                  xlockmore     3.0                                                                                                                                             xlockmore before 5.43 'dclock' security bypass vulnerability                              cpe:2.3:a:sillycycle:xlockmore:3.0:*:*:*:*:*:*:*                                                                                [[], [xlockmore], [before 5.43]]                                 [[], [0.99722517], [0.99928296]]           []                                                                         [xlockmore]                         [before 5.43]               []                        [0.99722517]             [0.99928296]           []                 []                       [xlockmore]        [0.99722517]                  xlockmore        sillycycle                          1
# 58     CVE-2006-3572     591848             papoo                      papoo   3.0.0                                             SQL injection vulnerability in forumthread.php in Papoo 3 RC3 and earlier allows remote attackers to execute arbitrary SQL commands via the msgid parameter.                                     cpe:2.3:a:papoo:papoo:3.0.0:*:*:*:*:*:*:*                                                                             [[], [papoo], [3, rc3 and earlier]]                      [[], [0.99351454], [0.98506606, 0.9989786]]           []                                                                             [papoo]                  [3, rc3 and earlier]               []                        [0.99351454]  [0.98506606, 0.9989786]           []                 []                           [papoo]        [0.99351454]                      papoo             papoo                          1
# 64  CVE-2018-1000140     509220           rsyslog                    librelp  1.2.11  rsyslog librelp version 1.2.14 and earlier contains a Buffer Overflow vulnerability in the checking of x509 certificates from a peer that can result in Remote code execution. This attack appear to...                                cpe:2.3:a:rsyslog:librelp:1.2.11:*:*:*:*:*:*:*                                                                    [[rsyslog], [librelp], [1.2.14 and earlier]]                        [[0.9850368], [0.55323046], [0.99993706]]    [rsyslog]                                                                           [librelp]                  [1.2.14 and earlier]      [0.9850368]                        [0.55323046]             [0.99993706]    [rsyslog]        [0.9850368]                         [librelp]        [0.55323046]                    librelp           rsyslog                          1
# 69     CVE-2014-2949     717314                f5           arx_data_manager   3.1.0                   SQL injection vulnerability in the web service in F5 ARX Data Manager 3.0.0 through 3.1.0 allows remote authenticated users to execute arbitrary SQL commands via unspecified vectors.                             cpe:2.3:a:f5:arx_data_manager:3.1.0:*:*:*:*:*:*:*                                                               [[f5], [arx data manager], [3.0.0 through 3.1.0]]                         [[0.9191322], [0.99354094], [0.9999458]]         [f5]                                                                  [arx data manager]                 [3.0.0 through 3.1.0]      [0.9191322]                        [0.99354094]              [0.9999458]         [f5]        [0.9191322]                [arx data manager]        [0.99354094]           arx_data_manager                f5                          1
# 72     CVE-2020-1977     467697  paloaltonetworks  expedition_migration_tool  1.1.10  Insufficient Cross-Site Request Forgery (XSRF) protection on Expedition Migration Tool allows remote unauthenticated attackers to hijack the authentication of administrators and to perform actions...     cpe:2.3:a:paloaltonetworks:expedition_migration_tool:1.1.10:*:*:*:*:*:*:*  [[], [expedition migration tool, expedition migration tool., expedition migration tool], [1.1.51 and earlier]]           [[], [0.9906509, 0.93002206, 0.9916379], [0.99737406]]           []  [expedition migration tool, expedition migration tool., expedition migration tool]                  [1.1.51 and earlier]               []  [0.9906509, 0.93002206, 0.9916379]             [0.99737406]           []                 []       [expedition migration tool]         [0.9916379]  expedition_migration_tool  paloaltonetworks                          1
# 74    CVE-2021-29642     621497   gistpad_project                    gistpad  0.0.12                                                               GistPad before 0.2.7 allows a crafted workspace folder to change the URL for the Gist API, which leads to leakage of GitHub access tokens.            cpe:2.3:a:gistpad_project:gistpad:0.0.12:*:*:*:*:visual_studio:*:*                                                                                 [[], [gistpad], [before 0.2.7]]                                  [[], [0.99954647], [0.9999367]]           []                                                                           [gistpad]                        [before 0.2.7]               []                        [0.99954647]              [0.9999367]           []                 []                         [gistpad]        [0.99954647]                    gistpad   gistpad_project                          1
# 75     CVE-2020-8034     501062             horde                     gollem   3.0.3  Gollem before 3.0.13, as used in Horde Groupware Webmail Edition 5.2.22 and other products, is affected by a reflected Cross-Site Scripting (XSS) vulnerability via the HTTP GET dir parameter in th...                                    cpe:2.3:a:horde:gollem:3.0.3:*:*:*:*:*:*:*                                                [[horde], [gollem, groupware webmail], [before 3.0.13,, 5.2.22]]  [[0.99866366], [0.9820202, 0.92137116], [0.9999332, 0.9998691]]      [horde]                                                         [gollem, groupware webmail]              [before 3.0.13,, 5.2.22]     [0.99866366]             [0.9820202, 0.92137116]   [0.9999332, 0.9998691]      [horde]       [0.99866366]                          [gollem]         [0.9820202]                     gollem             horde                          1
# 86     CVE-2001-1226     728719           adcycle                    adcycle    1.17                                                       AdCycle 1.17 and earlier allow remote attackers to modify SQL queries, which are not properly sanitized before being passed to the MySQL database.                                  cpe:2.3:a:adcycle:adcycle:1.17:*:*:*:*:*:*:*                                                                             [[], [adcycle], [1.17 and earlier]]                                   [[], [0.9997284], [0.9999426]]           []                                                                           [adcycle]                    [1.17 and earlier]               []                         [0.9997284]              [0.9999426]           []                 []                         [adcycle]         [0.9997284]                    adcycle           adcycle                          1

# %%
preprocessed_ner = classify_version_string('before 5.43')
generated_versions = generate_versions(*preprocessed_ner)

# %%
generated_versions[10000:10020]
# Out:
# ['1.0.0', '1.0.1', '1.0.2', '1.0.3', '1.0.4', '1.0.5', '1.0.6', '1.0.7', '1.0.8', '1.0.9', '1.0.10', '1.0.11', '1.0.12', '1.0.13', '1.0.14', '1.0.15', '1.0.16', '1.0.17', '1.0.18', '1.0.19']

# %%
created_cpe = []
for v in generated_versions:
    if v[0] == '1':
        created_cpe.append(f'cpe:2.3:a:sillycycle:xlockmore:{v}:*:*:*:*:*:*:*')

# %%
df_test[(df_test['matched_db_product'] == df_test['product']) &
        (df_test['matched_db_vendor'] == df_test['vendor']) &
        (df_test['true_version_in_predicted'] == 1)].sort_values('cve_id')[['cve_id', 'vendor', 'matched_db_vendor', 'product', 'matched_db_product', 'version']]
# Out:
#                cve_id                                    vendor                         matched_db_vendor                                             product                                  matched_db_product  version
# 47      CVE-2007-2829                                   madwifi                                   madwifi                                             madwifi                                             madwifi    0.9.2
# 145     CVE-2007-5391                                        hp                                        hp                                     select_identity                                     select_identity    4.1.8
# 151     CVE-2007-5630                                bbsprocess                                bbsprocess                                           bbportals                                           bbportals    1.6.2
# 168     CVE-2008-3168                             empire_server                             empire_server                                       empire_server                                       empire_server   4.2.20
# 185     CVE-2008-5335                                php-fusion                                php-fusion                                          php-fusion                                          php-fusion  6.01.15
# 102     CVE-2013-1881                                     gnome                                     gnome                                             librsvg                                             librsvg   2.18.2
# 99      CVE-2013-4580                                    gitlab                                    gitlab                                              gitlab                                              gitlab    4.0.0
# 103     CVE-2014-2341                                  cubecart                                  cubecart                                            cubecart                                            cubecart    5.2.3
# 170     CVE-2014-4301                                    ajenti                                    ajenti                                              ajenti                                              ajenti    1.2.6
# 98      CVE-2015-9277                                mailenable                                mailenable                                          mailenable                                          mailenable      6.5
# 24      CVE-2015-9438                   display-widgets_project                   display-widgets_project                                     display-widgets                                     display-widgets     1.23
# 92     CVE-2016-10126                                    splunk                                    splunk                                              splunk                                              splunk    6.2.3
# 154    CVE-2016-10223                                bigtreecms                                bigtreecms                                         bigtree_cms                                         bigtree_cms   4.1.16
# 166    CVE-2016-10532                        console-io_project                        console-io_project                                          console-io                                          console-io    1.1.0
# 9      CVE-2016-10714                                       zsh                                       zsh                                                 zsh                                                 zsh    4.2.2
# 38      CVE-2016-2054                                     xymon                                     xymon                                               xymon                                               xymon   4.3.20
# 57      CVE-2016-2516                                       ntp                                       ntp                                                 ntp                                                 ntp   4.3.72
# 78      CVE-2017-5670                                  riverbed                                  riverbed                                                rios                                                rios    9.2.0
# 133  CVE-2018-1000018                                     ovirt                                     ovirt                           ovirt-hosted-engine-setup                           ovirt-hosted-engine-setup    1.2.0
# 45     CVE-2018-12491                                     phpok                                     phpok                                               phpok                                               phpok  4.9.032
# 165    CVE-2018-16459                           exceljs_project                           exceljs_project                                             exceljs                                             exceljs    0.5.1
# 6      CVE-2019-13183                                    flarum                                    flarum                                              flarum                                              flarum    0.1.0
# 104    CVE-2019-14772                                 verdaccio                                 verdaccio                                           verdaccio                                           verdaccio    0.3.1
# 15     CVE-2019-14862                                knockoutjs                                knockoutjs                                            knockout                                            knockout    1.2.1
# 105     CVE-2019-5979                               najeebmedia                               najeebmedia                  personalized_woocommerce_cart_page                  personalized_woocommerce_cart_page      1.1
# 46      CVE-2019-9606  personal_video_collection_script_project  personal_video_collection_script_project                    personal_video_collection_script                    personal_video_collection_script    4.0.4
# 83      CVE-2019-9844                               khanacademy                               khanacademy                                     simple-markdown                                     simple-markdown    0.4.2
# 196    CVE-2020-11673                                total-soft                                total-soft                                     responsive_poll                                     responsive_poll    1.2.2
# 72     CVE-2020-15502                                duckduckgo                                duckduckgo                                          duckduckgo                                          duckduckgo   5.52.2
# 100    CVE-2020-17467                                     butok                                     butok                                                fnet                                                fnet    0.8.0
# 139     CVE-2020-7719                                   locutus                                   locutus                                             locutus                                             locutus    1.3.2
# 108     CVE-2020-7743                                    mathjs                                    mathjs                                              mathjs                                              mathjs   3.20.0
# 97      CVE-2020-7760                                codemirror                                codemirror                                          codemirror                                          codemirror   5.58.0
# 28      CVE-2020-7981                              rubygeocoder                              rubygeocoder                                            geocoder                                            geocoder    1.2.0
# 77     CVE-2021-21297                                   nodered                                   nodered                                            node-red                                            node-red   0.12.0
# 199    CVE-2021-21353                                     pugjs                                     pugjs                                                 pug                                                 pug   0.15.4
# 95     CVE-2021-24484                                   ays-pro                                   ays-pro  secure_copy_content_protection_and_content_locking  secure_copy_content_protection_and_content_locking    2.4.6
# 0      CVE-2021-34085                                glensawyer                                glensawyer                                             mp3gain                                             mp3gain    1.3.4
# 175    CVE-2021-39359                                     gnome                                     gnome                                              libgda                                              libgda   1.99.1
# 29      CVE-2021-4306                      terminal-kit_project                      terminal-kit_project                                        terminal-kit                                        terminal-kit  0.14.10
# 54      CVE-2022-2089                               bold-themes                               bold-themes                                   bold_page_builder                                   bold_page_builder    2.6.8
# 128    CVE-2022-21802                                  grapesjs                                  grapesjs                                            grapesjs                                            grapesjs   0.9.12
# 163    CVE-2022-24770                            gradio_project                            gradio_project                                              gradio                                              gradio    2.3.0
# 116    CVE-2022-25187                                   jenkins                                   jenkins                                        support_core                                        support_core     2.33
# 121     CVE-2022-4577                               goldplugins                               goldplugins                                   easy_testimonials                                   easy_testimonials   1.17.2
# 136    CVE-2022-46165                                 syncthing                                 syncthing                                           syncthing                                           syncthing  0.14.39
# 58      CVE-2022-4876                                   kaltura                                   kaltura                                             mwembed                                             mwembed     2.41
# 19     CVE-2023-23723                                    winwar                                    winwar                                    wp_email_capture                                    wp_email_capture    3.7.1
# 115    CVE-2023-23879                     php_execution_project                     php_execution_project                                       php_execution                                       php_execution    1.0.0
# 107    CVE-2023-29439                                fooplugins                                fooplugins                                          foogallery                                          foogallery   2.0.30
# 135     CVE-2023-3957                                      navz                                      navz                             acf_photo_gallery_field                             acf_photo_gallery_field    1.5.0
# 84      CVE-2023-4482                                michaeluno                                michaeluno                                   auto_amazon_links                                   auto_amazon_links   4.6.22
# 147    CVE-2023-47619                            audiobookshelf                            audiobookshelf                                      audiobookshelf                                      audiobookshelf    2.3.2
# 20     CVE-2023-52323                              pycryptodome                              pycryptodome                                        pycryptodome                                        pycryptodome   3.15.0
# 23      CVE-2023-6998                                   coolkit                                   coolkit                                             ewelink                                             ewelink   4.13.1
# 39      CVE-2024-1078                                   ays-pro                                   ays-pro                                          quiz_maker                                          quiz_maker    5.4.1

# %%
df_test[(df_test['matched_db_product_lev'] == df_test['product']) &
        (df_test['matched_db_vendor_lev'] == df_test['vendor']) &
        (df_test['true_version_in_predicted'] == 1)].sort_values('cve_id')[['cve_id', 'vendor', 'matched_db_vendor_lev', 'matched_db_vendor' , 'product', 'matched_db_product_lev', 'matched_db_product', 'version', 'score_lev']]
# Out:
#                cve_id                                    vendor                     matched_db_vendor_lev                         matched_db_vendor                             product              matched_db_product_lev                                       matched_db_product  version  score_lev
# 47      CVE-2007-2829                                   madwifi                                   madwifi                                   madwifi                             madwifi                             madwifi                                                  madwifi    0.9.2   1.000000
# 145     CVE-2007-5391                                        hp                                        hp                                        hp                     select_identity                     select_identity                                          select_identity    4.1.8   0.933333
# 151     CVE-2007-5630                                bbsprocess                                bbsprocess                                bbsprocess                           bbportals                           bbportals                                                bbportals    1.6.2   1.000000
# 168     CVE-2008-3168                             empire_server                             empire_server                             empire_server                       empire_server                       empire_server                                            empire_server   4.2.20   0.923077
# 185     CVE-2008-5335                                php-fusion                                php-fusion                                php-fusion                          php-fusion                          php-fusion                                               php-fusion  6.01.15   1.000000
# 119     CVE-2011-2727                                    tribiq                                    tribiq                                    oracle                          tribiq_cms                          tribiq_cms        financial_services_basel_regulatory_capital_basic    5.0.9   0.666667
# 191     CVE-2012-6713                             wp-jobmanager                             wp-jobmanager                                   hitachi                         job_manager                         job_manager  job_management_partner_1\/it_desktop_management-manager    0.7.8   0.909091
# 102     CVE-2013-1881                                     gnome                                     gnome                                     gnome                             librsvg                             librsvg                                                  librsvg   2.18.2   0.923077
# 99      CVE-2013-4580                                    gitlab                                    gitlab                                    gitlab                              gitlab                              gitlab                                                   gitlab    4.0.0   1.000000
# 103     CVE-2014-2341                                  cubecart                                  cubecart                                  cubecart                            cubecart                            cubecart                                                 cubecart    5.2.3   1.000000
# 170     CVE-2014-4301                                    ajenti                                    ajenti                                    ajenti                              ajenti                              ajenti                                                   ajenti    1.2.6   1.000000
# 98      CVE-2015-9277                                mailenable                                mailenable                                mailenable                          mailenable                          mailenable                                               mailenable      6.5   1.000000
# 24      CVE-2015-9438                   display-widgets_project                   display-widgets_project                   display-widgets_project                     display-widgets                     display-widgets                                          display-widgets     1.23   1.000000
# 92     CVE-2016-10126                                    splunk                                    splunk                                    splunk                              splunk                              splunk                                                   splunk    6.2.3   1.000000
# 154    CVE-2016-10223                                bigtreecms                                bigtreecms                                bigtreecms                         bigtree_cms                         bigtree_cms                                              bigtree_cms   4.1.16   0.909091
# 166    CVE-2016-10532                        console-io_project                        console-io_project                        console-io_project                          console-io                          console-io                                               console-io    1.1.0   1.000000
# 9      CVE-2016-10714                                       zsh                                       zsh                                       zsh                                 zsh                                 zsh                                                      zsh    4.2.2   1.000000
# 38      CVE-2016-2054                                     xymon                                     xymon                                     xymon                               xymon                               xymon                                                    xymon   4.3.20   1.000000
# 57      CVE-2016-2516                                       ntp                                       ntp                                       ntp                                 ntp                                 ntp                                                      ntp   4.3.72   1.000000
# 78      CVE-2017-5670                                  riverbed                                  riverbed                                  riverbed                                rios                                rios                                                     rios    9.2.0   1.000000
# 133  CVE-2018-1000018                                     ovirt                                     ovirt                                     ovirt           ovirt-hosted-engine-setup           ovirt-hosted-engine-setup                                ovirt-hosted-engine-setup    1.2.0   1.000000
# 179  CVE-2018-1000603                                   jenkins                                   jenkins                                      suse                     openstack_cloud                     openstack_cloud                                  openstack_cloud_crowbar     2.23   0.756757
# 45     CVE-2018-12491                                     phpok                                     phpok                                     phpok                               phpok                               phpok                                                    phpok  4.9.032   1.000000
# 165    CVE-2018-16459                           exceljs_project                           exceljs_project                           exceljs_project                             exceljs                             exceljs                                                  exceljs    0.5.1   1.000000
# 37     CVE-2018-18551                              serverscheck                              serverscheck                                     cisco                 monitoring_software                 monitoring_software         telepresence_video_communication_server_software    5.0.0   0.705882
# 6      CVE-2019-13183                                    flarum                                    flarum                                    flarum                              flarum                              flarum                                                   flarum    0.1.0   1.000000
# 104    CVE-2019-14772                                 verdaccio                                 verdaccio                                 verdaccio                           verdaccio                           verdaccio                                                verdaccio    0.3.1   1.000000
# 15     CVE-2019-14862                                knockoutjs                                knockoutjs                                knockoutjs                            knockout                            knockout                                                 knockout    1.2.1   1.000000
# 105     CVE-2019-5979                               najeebmedia                               najeebmedia                               najeebmedia  personalized_woocommerce_cart_page  personalized_woocommerce_cart_page                       personalized_woocommerce_cart_page      1.1   0.911765
# 46      CVE-2019-9606  personal_video_collection_script_project  personal_video_collection_script_project  personal_video_collection_script_project    personal_video_collection_script    personal_video_collection_script                         personal_video_collection_script    4.0.4   0.840580
# 83      CVE-2019-9844                               khanacademy                               khanacademy                               khanacademy                     simple-markdown                     simple-markdown                                          simple-markdown    0.4.2   1.000000
# 196    CVE-2020-11673                                total-soft                                total-soft                                total-soft                     responsive_poll                     responsive_poll                                          responsive_poll    1.2.2   0.933333
# 72     CVE-2020-15502                                duckduckgo                                duckduckgo                                duckduckgo                          duckduckgo                          duckduckgo                                               duckduckgo   5.52.2   1.000000
# 100    CVE-2020-17467                                     butok                                     butok                                     butok                                fnet                                fnet                                                     fnet    0.8.0   1.000000
# 139     CVE-2020-7719                                   locutus                                   locutus                                   locutus                             locutus                             locutus                                                  locutus    1.3.2   1.000000
# 108     CVE-2020-7743                                    mathjs                                    mathjs                                    mathjs                              mathjs                              mathjs                                                   mathjs   3.20.0   1.000000
# 97      CVE-2020-7760                                codemirror                                codemirror                                codemirror                          codemirror                          codemirror                                               codemirror   5.58.0   1.000000
# 28      CVE-2020-7981                              rubygeocoder                              rubygeocoder                              rubygeocoder                            geocoder                            geocoder                                                 geocoder    1.2.0   1.000000
# 77     CVE-2021-21297                                   nodered                                   nodered                                   nodered                            node-red                            node-red                                                 node-red   0.12.0   1.000000
# 199    CVE-2021-21353                                     pugjs                                     pugjs                                     pugjs                                 pug                                 pug                                                      pug   0.15.4   1.000000
# 180    CVE-2021-28117                                       kde                                       kde                                trendmicro                            discover                            discover                                  deep_discovery_analyzer   5.18.0   0.800000
# 0      CVE-2021-34085                                glensawyer                                glensawyer                                glensawyer                             mp3gain                             mp3gain                                                  mp3gain    1.3.4   1.000000
# 175    CVE-2021-39359                                     gnome                                     gnome                                     gnome                              libgda                              libgda                                                   libgda   1.99.1   1.000000
# 29      CVE-2021-4306                      terminal-kit_project                      terminal-kit_project                      terminal-kit_project                        terminal-kit                        terminal-kit                                             terminal-kit  0.14.10   1.000000
# 54      CVE-2022-2089                               bold-themes                               bold-themes                               bold-themes                   bold_page_builder                   bold_page_builder                                        bold_page_builder    2.6.8   0.882353
# 128    CVE-2022-21802                                  grapesjs                                  grapesjs                                  grapesjs                            grapesjs                            grapesjs                                                 grapesjs   0.9.12   1.000000
# 163    CVE-2022-24770                            gradio_project                            gradio_project                            gradio_project                              gradio                              gradio                                                   gradio    2.3.0   0.857143
# 116    CVE-2022-25187                                   jenkins                                   jenkins                                   jenkins                        support_core                        support_core                                             support_core     2.33   0.916667
# 121     CVE-2022-4577                               goldplugins                               goldplugins                               goldplugins                   easy_testimonials                   easy_testimonials                                        easy_testimonials   1.17.2   0.941176
# 136    CVE-2022-46165                                 syncthing                                 syncthing                                 syncthing                           syncthing                           syncthing                                                syncthing  0.14.39   1.000000
# 88      CVE-2022-4623                                   nicdark                                   nicdark                                 bedevious                       nd_shortcodes                       nd_shortcodes          password_reset_with_code_for_wordpress_rest_api      5.3   0.666667
# 58      CVE-2022-4876                                   kaltura                                   kaltura                                   kaltura                             mwembed                             mwembed                                                  mwembed     2.41   1.000000
# 19     CVE-2023-23723                                    winwar                                    winwar                                    winwar                    wp_email_capture                    wp_email_capture                                         wp_email_capture    3.7.1   0.875000
# 115    CVE-2023-23879                     php_execution_project                     php_execution_project                     php_execution_project                       php_execution                       php_execution                                            php_execution    1.0.0   0.923077
# 107    CVE-2023-29439                                fooplugins                                fooplugins                                fooplugins                          foogallery                          foogallery                                               foogallery   2.0.30   1.000000
# 135     CVE-2023-3957                                      navz                                      navz                                      navz             acf_photo_gallery_field             acf_photo_gallery_field                                  acf_photo_gallery_field    1.5.0   0.869565
# 84      CVE-2023-4482                                michaeluno                                michaeluno                                michaeluno                   auto_amazon_links                   auto_amazon_links                                        auto_amazon_links   4.6.22   0.882353
# 147    CVE-2023-47619                            audiobookshelf                            audiobookshelf                            audiobookshelf                      audiobookshelf                      audiobookshelf                                           audiobookshelf    2.3.2   1.000000
# 20     CVE-2023-52323                              pycryptodome                              pycryptodome                              pycryptodome                        pycryptodome                        pycryptodome                                             pycryptodome   3.15.0   1.000000
# 23      CVE-2023-6998                                   coolkit                                   coolkit                                   coolkit                             ewelink                             ewelink                                                  ewelink   4.13.1   1.000000
# 39      CVE-2024-1078                                   ays-pro                                   ays-pro                                   ays-pro                          quiz_maker                          quiz_maker                                               quiz_maker    5.4.1   0.900000
# 140    CVE-2024-24866                                  biteship                                  biteship                                resalecode                            biteship                            biteship                            hutscripts_php_website_script   2.2.11   0.615385

# %%
df_test[
        (df_test['matched_db_product_lev'] != df_test['product'])].sort_values('cve_id')[['cve_id', 'vendor', 'matched_db_vendor_lev', 'matched_db_vendor', 'product', 'product_ner', 'matched_db_product_lev', 'matched_db_product', 'version', 'score_lev']]
# Out:
#                cve_id                                       vendor    matched_db_vendor_lev                                matched_db_vendor                                                                        product                                                                                                                                                                                              product_ner              matched_db_product_lev                                                                     matched_db_product           version  score_lev
# 172     CVE-2004-0095                                       mcafee       network_associates                               network_associates                                                           epolicy_orchestrator                                                                                                                                                                             [epolicy orchestrator agent]          epolicy_orchestrator_agent                                                             epolicy_orchestrator_agent             3.6.0   0.923077
# 125     CVE-2005-2631                                        cisco                      ibm                                           wpruby                   network_admission_control_manager_and_server_system_software                                                                                                                                                                                           [clean access]                       client_access                                                                controlled_admin_access             3.5.2   0.800000
# 11      CVE-2006-5093                                 paul_schudar                    tagit                                            tagit                                                          tagmin_control_center                                                                                                                                                                                               [tagboard]                            tagboard                                                                               tagboard     2.1.b_build_2   1.000000
# 80      CVE-2006-6274                                 expinion.net                                                                                                                                             news_manager                                                                                                                                                                                                       []                                                                                                                                          NaN   0.000000
# 52      CVE-2007-0851                                  trend_micro                                                                                                                                       web_security_suite                                                                                                                                                                                                       []                                                                                                                                        1.2.0   0.000000
# 120     CVE-2007-3381                                        gnome                     dell                                             dell                                                                            gdm                                                                                                                                                                                        [display manager]                     display_manager                                                                        display_manager               2.2   0.933333
# 71      CVE-2009-1729                                          sun               sb-websoft                     professional_home_page_tools                                             java_system_communications_express                                                                                                                                                      [java system communications, personal address book]                         addressbook                                                 professional_home_page_tools_guestbook               6.3   0.687500
# 68      CVE-2012-4524                                   sillycycle                                                                                                                                                xlockmore                                                                                                                                                                                                       []                                                                                                                                          2.3   0.000000
# 5       CVE-2013-3607                                   supermicro                                                                                                                                                 x9dax-if                                                                                                                                                                                                       []                                                                                                                                            -   0.000000
# 35      CVE-2013-6440                                    internet2               shibboleth                                       shibboleth                                                                       opensaml                                                                                                                                                                                          [opensaml-java]                       opensaml_java                                                                          opensaml_java             2.2.0   0.923077
# 113     CVE-2014-2008                               mpay24_project                   remise                                          paysafe                                                                         mpay24                                                                                                                                                                                  [mpay24 payment module]                      payment_module                                                       barzahlen_payment_module_php_sdk             1.4.8   0.742857
# 122     CVE-2014-5867                                     sparkpay                 divisait                                         divisait                                                              capital_one_spark                                                                                                                                                                                              [spark pay]                          sparkspace                                                                             sparkspace            0.9.81   0.736842
# 1       CVE-2014-7221                                    teamspeak                teamspeak                                        teamspeak                                                                     teamspeak3                                                                                                                                                                                              [teamspeak]                           teamspeak                                                                              teamspeak           3.0.7.1   1.000000
# 14      CVE-2015-8076                                        cyrus                cyrusimap                                        cyrusimap                                                                           imap                                                                                                                                                                                             [cyrus imap]                          cyrus_imap                                                                             cyrus_imap             2.5.2   0.900000
# 143    CVE-2016-10581                                     appgyver                                                                                                                                                 steroids                                                                                                                                                                                                       []                                                                                                                                        3.1.3   0.000000
# 33      CVE-2016-1409                                        cisco                                                                                                                                                      ios                                                                                                                                                                                                       []                                                                                                                                 12.1\(1\)xd2   0.000000
# 87      CVE-2016-6399                                        cisco                                                                                                                 ace_application_control_engine_module_a4                                                                                                                                                                                                       []                                                                                                                                          1.0   0.000000
# 43      CVE-2017-5703                                        intel                                                                                                                                          xeon_e7-8870_v3                                                                                                                                                                                                       []                                                                                                                                            -   0.000000
# 159     CVE-2017-6753                                        cisco                    cisco                                            cisco                                            webex_meetings_server_2.6_mr2_patch                                                                                                             [webex, webex meetings server,, webex centers, center,, webex meetings, webex, webex, webex]                      webex_meetings                                                                         webex_meetings                 1   0.928571
# 66      CVE-2018-0463                                        cisco                                                                                                                            network_services_orchestrator                                                                                                                                                                                                       []                                                                                                                                        1.2.0   0.000000
# 162  CVE-2018-1000417                                      jenkins                  jenkins                                          jenkins                                                       email_extension_template                                                                                                                                                                         [jenkins email, template plugin]                             jenkins                                                          jenkins-cloudformation-plugin               0.2   0.700000
# 124  CVE-2018-1000831                                       k9mail                      kde                                           k9mail                                                                       k-9_mail                                                                                                                                                                                                 [k9mail]                               kmail                                                                               k-9_mail             2.506   0.909091
# 112  CVE-2018-1000888                                          php                     pear                                             pear                                                               pear_archive_tar                                                                                                                                                                                                   [pear]                                pear                                                                                   pear             1.3.9   1.000000
# 7      CVE-2018-15121                                        auth0                atlassian                                        atlassian                                                                         aspnet                                                                                                                                                                    [auth0-aspnet, oauth, openid connect]                               oauth                                                                                  oauth                 -   1.000000
# 127    CVE-2018-20801                                   highcharts                       f5                                               f5                                                                     highcharts                                                                                                                                                                                                     [js]                                 njs                                                                                    njs             4.1.6   0.800000
# 67      CVE-2018-3778                                aedes_project                                                                                                                                                    aedes                                                                                                                                                                                                       []                                                                                                                                       0.25.1   0.000000
# 2       CVE-2018-7279                                   alienvault            peter_d._gray                                          usermin                                    open_source_security_information_management                                                                                                                                                                                                    [usm]                                 sus                                                                                usermin               5.3   0.666667
# 198    CVE-2019-20903                                    atlassian                                                                                                                                              editor-core                                                                                                                                                                                                       []                                                                                                                                       98.2.2   0.000000
# 70     CVE-2019-25056                                      bromite                                                                                                                                                  bromite                                                                                                                                                                                                       []                                                                                                                                 73.0.3683.79   0.000000
# 53     CVE-2020-10591                                      walmart                                                                                                                                                  concord                                                                                                                                                                                                       []                                                                                                                                       0.72.0   0.000000
# 142    CVE-2020-13401                                       docker               yogeshojha                                            cisco                                                                         engine                                                                                                                                                                                          [docker engine]                             rengine                                                virtualized_packet_core-single_instance            1.13.1   0.700000
# 161    CVE-2020-15003                                 open-xchange             open-xchange                                     open-xchange                                                          open-xchange_appsuite                                                                                                                                                                                           [ox app suite]                        ox_app_suite                                                                           ox_app_suite            7.10.3   0.833333
# 123    CVE-2020-16116                                          kde              entropymine                                              kde                                                                            ark                                                                                                                                                                                                [kde ark]                               deark                                                                         kde_frameworks             4.7.0   0.833333
# 82      CVE-2020-2090                                      jenkins                  jenkins                                          jenkins                                                                     amazon_ec2                                                                                                                                                                                                    [ec2]                                 ec2                                                                                    ec2               1.9   1.000000
# 55     CVE-2020-23622                                cling_project                 indusoft                                              ibm                                                                          cling                                                                                                                                                                                          [4thline cling]                         thin_client                                                        tivoli_netcool_security_manager             2.0.0   0.666667
# 3      CVE-2020-24743                                     zohocorp             manageengine                                     manageengine                                              manageengine_applications_manager                                                                                                                                                                                   [applications manager]                applications_manager                                                                   applications_manager              14.5   0.950000
# 4      CVE-2020-24786                                     zohocorp                      sun                                              sun                                                 manageengine_o365_manager_plus  [manageengine exchange reporter plus, adselfservice plus, datasecurity plus, recovermanager plus, eventlog analyzer, adaudit plus, o365 manager plus, cloud security plus, admanager plus, log360, j...                     java_asp_server                                   java_communications_services_delegated_administrator               4.3   0.666667
# 189     CVE-2020-4038                                       prisma                   prisma                                           prisma                                                        graphql-playground-html                            [graphql-playground-html, graphql-playground-middleware-express, graphql-playground-middleware-koa, graphql-playground-middleware-lambda, graphql-playground-middleware-hapi]  graphql-playground-middleware-hapi                                                     graphql-playground-middleware-hapi             1.4.3   1.000000
# 174     CVE-2020-7934                                      liferay                infovista                                          fujitsu                                                                 liferay_portal                                                                                                                                                                                   [portal ce, portal ce]                            portalse                                                                    myweb_portal_office             7.2.0   0.823529
# 109    CVE-2021-24348                                   wow-estore                wordpress                                        wordpress                                                                      side_menu                                                                                                                                                                                              [wordpress]                           wordpress                                                                              wordpress               3.1   1.000000
# 194    CVE-2021-24472                                 qantumthemes             qantumthemes                                     qantumthemes                                                                         onair2                                                                                                                                                                      [wordpress, kentharadio, wordpress]                         kentharadio                                                                            kentharadio             3.9.3   1.000000
# 95     CVE-2021-24484                                      ays-pro   content_rating_project                                          ays-pro                             secure_copy_content_protection_and_content_locking                                                                                                                                                                             [content locking, wordpress]                      content_rating                                     secure_copy_content_protection_and_content_locking             2.4.6   0.689655
# 177    CVE-2021-28306                                 fltk_project             ninjadesigns                                         wclovers                                                                           fltk                                                                                                                                                                                             [fltk crate]                            flatchat  frontend_manager_for_woocommerce_along_with_bookings_subscription_listings_compatible            0.12.0   0.666667
# 93     CVE-2021-30476                                    hashicorp                hashicorp                                              ibm                                                             terraform_provider                                                                                                                                                                                            [terraform’s]                           terraform                                                       water_operations_for_waternamics             1.3.1   0.900000
# 192    CVE-2021-33176                                   octavolabs                   redhat                                   chris_buccella                                                                        vernemq                                                                                                                                                                                            [mqtt broker]                          amq_broker                                                             small_footprint_cim_broker             1.0.0   0.761905
# 110     CVE-2021-3829                                     openwhyd                                                                                                                                                 openwhyd                                                                                                                                                                                                       []                                                                                                                                       1.44.8   0.000000
# 158    CVE-2021-39317                            accesspressthemes        accesspressthemes                                accesspressthemes                                                                eightstore-lite  [wordpress, wordpress, wordpress, accesspress, demo importer, wordpress, accesspress-basic, accesspress-lite, accesspress-mag, accesspress-parallax, accesspress-root, accesspress-store, agency-lit...                          zigcy-baby                                                                             zigcy-baby            1.0.86   1.000000
# 42     CVE-2021-45099                  ssh_\&_web_terminal_project         bluecat_networks                                           sysaid                                                            ssh_\&_web_terminal                                                                                                                                                                                              [addon-ssh]                              adonis                                                                     sysaid_on-premises             8.0.4   0.666667
# 73      CVE-2022-0208                                  mappresspro                wordpress                                        wordpress                                                                       mappress                                                                                                                                                                               [mappress maps, wordpress]                           wordpress                                                                              wordpress            2.49.2   1.000000
# 117     CVE-2022-0271                                    thimpress                wordpress                                        wordpress                                                                     learnpress                                                                                                                                                                                              [wordpress]                           wordpress                                                                              wordpress             3.0.0   1.000000
# 75      CVE-2022-0864                                  updraftplus                wordpress              wordpress_backup_to_dropbox_project                                                                    updraftplus                                                                                                                                                                            [wordpress backup, wordpress]                           wordpress                                                            wordpress_backup_to_dropbox            1.9.64   0.720000
# 160     CVE-2022-0959                                   postgresql                                                                                                                                                pgadmin_4                                                                                                                                                                                                       []                                                                                                                                          4.1   0.000000
# 64      CVE-2022-0991                                      admidio                                                                                                                                                  admidio                                                                                                                                                                                                       []                                                                                                                                        3.1.2   0.000000
# 197     CVE-2022-1253                                     struktur                                                                                                                                                 libde265                                                                                                                                                                                                       []                                                                                                                                        1.0.3   0.000000
# 169     CVE-2022-1435                                  wptaskforce            juan_cespedes                                    juan_cespedes                                                                 track_\&_trace                                                                                                                                                                                       [trace, wordpress]                              ltrace                                                                                 ltrace             6.4.0   0.909091
# 89     CVE-2022-22984                                         snyk                     snyk                                             snyk                                                                       snyk_cli                                                                                     [snyk, snyk-mvn-plugin, snyk-gradle-plugin, snyk-sbt-plugin, snyk-python-plugin, snyk-docker-plugin, snyk, teamcity]                     snyk_gradle_cli                                                                        snyk_gradle_cli             1.3.1   0.727273
# 26     CVE-2022-23179                                    themehunk                wordpress                                        wordpress                                    contact_form_\&_lead_form_elementor_builder                                                                                                                                                                           [elementor builder, wordpress]                           wordpress                                                                              wordpress             1.5.0   1.000000
# 146     CVE-2022-2373                                        nsqua                wordpress                                        wordpress                                                   simply_schedule_appointments                                                                                                                                                     [simply schedule appointments, wordpress, wordpress]                           wordpress                                                                              wordpress           1.4.9.5   1.000000
# 61     CVE-2022-24436                                        intel                                                                                                                                                  core_i5                                                                                                                                                                                                       []                                                                                                                                        4202y   0.000000
# 31     CVE-2022-24709                                       amazon                 facebook                                         facebook                                                        awsui\/components-react                                                                                                                                                                                              [ui, react]                               react                                                                                  react           3.0.139   1.000000
# 111     CVE-2022-2696                                       oracle              enthrallweb  food-order-and-table-reservation-system_project                     restaurant_menu_-_food_ordering_system_-_table_reservation                                                                                                                                                                                      [table reservation]                       ereservations                                                food-order-and-table-reservation-system             1.3.1   0.800000
# 141     CVE-2022-2713                                     agentejo                                                                                                                                                  cockpit                                                                                                                                                                                                       []                                                                                                                                        0.8.8   0.000000
# 16     CVE-2022-32169                                     bytebase                                                                                                                                                 bytebase                                                                                                                                                                                                       []                                                                                                                                        0.8.1   0.000000
# 27     CVE-2022-34868                                     yookassa              woocommerce                                      woocommerce                                                        yukassa_for_woocommerce                                                                                                                                                                                            [woocommerce]                         woocommerce                                                                            woocommerce             2.1.4   1.000000
# 118    CVE-2022-35404                                     zohocorp             manageengine                                     manageengine                                     manageengine_network_configuration_manager                                                                                                                                                                        [password manager pro, opmanager]                           opmanager                                                                              opmanager              12.5   1.000000
# 195     CVE-2022-3550                                        x.org                        x                                                x                                                                       x_server                                                                                                                                                                                          [x.org server.]                       x.org-xserver                                                                          x.org-xserver            1.13.1   0.846154
# 12      CVE-2022-3768                             wpsmartcontracts                wordpress                                        wordpress                                                               wpsmartcontracts                                                                                                                                                                            [wpsmartcontracts, wordpress]                           wordpress                                                                              wordpress             1.2.2   1.000000
# 150    CVE-2022-38754                                   microfocus                    clerk                                           matrix                                                      operations_bridge_manager                                                                                         [java scripts, focus operations bridge manager, java scripts, focus operations bridge manager, focus operations]                          javascript                                                                         javascript_sdk           2020.05   0.909091
# 156    CVE-2022-40897                                       python                                                                                                                                               setuptools                                                                                                                                                                                                       []                                                                                                                                       64.0.0   0.000000
# 176    CVE-2022-42188                                     lavalite                                                                                                                                                 lavalite                                                                                                                                                                                                       []                                                                                                                                        9.0.0   0.000000
# 188    CVE-2022-45544                                       schlix  six_offene_systeme_gmbh                                           heator                                                                            cms                                                                                                                                                                                             [schlix cms]                              sixcms                                        social_share\,_social_login_and_social_comments           2.2.7-2   0.750000
# 22      CVE-2022-4578         video_conferencing_with_zoom_project                wordpress                                       highfivery                                                   video_conferencing_with_zoom                                                                                                                                                                                         [zoom wordpress]                           wordpress                                                                zero_spam_for_wordpress            3.6.23   0.782609
# 183     CVE-2022-4790  auto_publish_for_google_my_business_project                 wpswings                                              sap                                            auto_publish_for_google_my_business                                                                                                                                                           [wp google my business auto publish wordpress]         pdf_generator_for_wordpress                       process_integration_\(pgp_module_-_business-to-business_add_on\)              2.17   0.478873
# 48      CVE-2023-0816                                   strategy11               strategy11                                       themekraft                                                        formidable_form_builder                                                                                                                                                                             [formidable forms wordpress]                    formidable_forms           post_form_registration_form_profile_form_for_user_profiles_and_content_forms           4.04.04   0.714286
# 36     CVE-2023-20903                                 cloudfoundry                                                                                                                          user_account_and_authentication                                                                                                                                                                                                       []                                                                                                                                        3.9.4   0.000000
# 63     CVE-2023-21420                                      samsung                  jenkins                                          jenkins                                                                        android                                                                                                                                                                                                   [stst]                              mstest                                                                                 mstest              10.0   0.800000
# 155    CVE-2023-23684                                     wpengine                                                                                                                                                wpgraphql                                                                                                                                                                                                       []                                                                                                                                        1.5.5   0.000000
# 69     CVE-2023-26262                                     sitecore                                                                                                                                      experience_platform                                                                                                                                                                                                       []                                                                                                                                          9.0   0.000000
# 41     CVE-2023-28110                                    fit2cloud               jumpserver                                       jumpserver                                                                           koko                                                                                                                                                                     [jumpserver, koko, jumpserver, koko]                          jumpserver                                                                             jumpserver                 -   1.000000
# 153    CVE-2023-35625                                    microsoft                                                                                                          azure_machine_learning_software_development_kit                                                                                                                                                                                                       []                                                                                                                                        0.1.0   0.000000
# 149    CVE-2023-37868                                       leap13         bluecat_networks                                            tibco                                                                 premium_addons                                                                                                                                                                                 [premium addons, addons]                              adonis                                                                            ebx_add-ons             2.0.6   0.833333
# 17     CVE-2023-48795                            filezilla-project                 paramiko                                         paramiko                                                               filezilla_client  [openssh, openssh, java ssh api, putty, asyncssh, libssh, libssh2, sftp gateway, tera term, paramiko, jsch, sftpgo, pfsense plus, hpn-ssh, proftpd, cyclonessh, xshell, crushftp, connectbot, ssh li...                            paramiko                                                                               paramiko             3.9.0   1.000000
# 65     CVE-2023-49183                                  nextscripts                                                                                                                              social_networks_auto_poster                                                                                                                                                                                                       []                                                                                                                                       4.3.14   0.000000
# 51     CVE-2023-51652                                    spassarop         antisamy_project                                 antisamy_project                                                            owasp_antisamy_.net                                                                                                                      [antisamy, .net, antisamy, antisamy, .net, antisamy, antisamy, antisamy, antisamy.]                            antisamy                                                                               antisamy             1.0.3   1.000000
# 126     CVE-2023-6158                                    myeventon                myeventon                                        myeventon                                                                   eventon-lite                                                                                                                                                                        [eventon, virtual event calendar]                             eventon                                                                                eventon             2.2.6   1.000000
# 164     CVE-2023-7068                                    webtoffee                  sepcity                                       visztpeter  woocommerce_pdf_invoices\,_packing_slips\,_delivery_notes_and_shipping_labels                                                                                                                                                                        [delivery notes, shipping labels]                       shopping_mall                                     package_points_and_shipping_labels_for_woocommerce             2.6.6   0.642857
# 181    CVE-2024-20692                                    microsoft                    ocaml                                localizer_project                                                                windows_10_1507                                                                                                                                                                                                  [local]                               ocaml                                                                              localizer  10.0.10240.19204   0.800000
# 34     CVE-2024-20803                                      samsung                                                                                                                                                  android                                                                                                                                                                                                       []                                                                                                                                         13.0   0.000000
# 44     CVE-2024-22075                                  firefly-iii                  firefly                                          firefly                                                                    firefly_iii                                                                                                                                                                                                [firefly]                             firefly                                                                                firefly             5.7.5   1.000000
# 76     CVE-2024-24396                                   stimulsoft          emlsoft_project                                            cisco                                                                   dashboard.js                                                                                                                                                                                             [stimulsoft]                             emlsoft                                        ons_15216_optical_add_drop_multiplexer_software          2022.4.3   0.705882
# 30     CVE-2024-24831                                       leap13                                                                                                                             premium_addons_for_elementor                                                                                                                                                                                                       []                                                                                                                                        4.1.4   0.000000

# %% [markdown]
# * Для CVE-2007-6487 продукта webgui есть вендор plainblack и plain_black в БД
#
# * Для CVE-2004-0095 есть продукт epolicy_orchestrator_agent и epolicy_orchestrator в БД
#
# * Для CVE-2007-3381 продукт gdm -- абревиатура, не найти такой продукт в БД
#
# * CVE-2013-6440 есть продукт opensaml и opensaml_java в БД
#
# * CVE-2014-7221 есть продукт teamspeak и teamspeak3 в БД
#
# * CVE-2020-15003 дубли продукта в БД open-xchange_appsuite и ox_app_suite, оба версии 7.10.5
# 7.10.5

# %%
epolicy_orchestrator

# %%
'job_manager' in unique_products
# Out:
# True
